# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_excel("team_data/소비유형별.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 df = pd.read_excel("team_data/소비유형별.xlsx")
#
# File C:\Python\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File C:\Python\anaconda3\lib\site-packages\pandas\io\excel\_base.py:457, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     455 if not isinstance(io, ExcelFile):
#     456     should_close = True
# --> 457     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     458 elif engine and engine != io.engine:
#     459     raise ValueError(
#     460         "Engine should not be specified when passing "
#     461         "an ExcelFile - ExcelFile already has the engine set"
#     462     )
#
# File C:\Python\anaconda3\lib\site-packages\pandas\io\excel\_base.py:1376, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1374     ext = "xls"
#    1375 else:
# -> 1376     ext = inspect_excel_format(
#    1377         content_or_path=path_or_buffer, storage_options=storage_options
#    1378     )
#    1379     if ext is None:
#    1380         raise ValueError(
#    1381             "Excel file format cannot be determined, you must specify "
#    1382             "an engine manually."
#    1383         )
#
# File C:\Python\anaconda3\lib\site-packages\pandas\io\excel\_base.py:1250, in inspect_excel_format(content_or_path, storage_options)
#    1247 if isinstance(content_or_path, bytes):
#    1248     content_or_path = BytesIO(content_or_path)
# -> 1250 with get_handle(
#    1251     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1252 ) as handle:
#    1253     stream = handle.handle
#    1254     stream.seek(0)
#
# File C:\Python\anaconda3\lib\site-packages\pandas\io\common.py:798, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#    (...)
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
# --> 798         handle = open(handle, ioargs.mode)
#     799     handles.append(handle)
#     801 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'team_data/소비유형별.xlsx'

# %%
df.head(5)

# %%
df = df.T
tcard = df[0]
tcard
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 df = df.T
#       2 tcard = df[0]
#       3 tcard
#
# NameError: name 'df' is not defined

# %%
type(tcard)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 type(tcard)
#
# NameError: name 'tcard' is not defined

# %%
tcard.index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 tcard.index
#
# NameError: name 'tcard' is not defined

# %%
tcard = tcard[6:]
tcard.tail(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 tcard = tcard[6:]
#       2 tcard.tail(5)
#
# NameError: name 'tcard' is not defined

# %%
type(tcard)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 type(tcard)
#
# NameError: name 'tcard' is not defined

# %%
tcard.name = '월별카드매출액'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 tcard.name = '월별카드매출액'
#
# NameError: name 'tcard' is not defined

# %%
tcard.values
# Out:
# array([44936072, 38921767, 44496876, 43591233, 46109266, 43594544,
#        46211620, 45275053, 43921467, 46599097, 46743092, 48407568,
#        47333540, 41266091, 41916271, 43066211, 46919475, 46392367,
#        47806147, 46377231, 47128339, 47304200, 47680752, 46881759,
#        46268277, 44023439, 49869479, 48970480, 51219562, 50209911,
#        52583282, 50076065, 50710469, 53469616, 53827378, 53993508,
#        54539492, 47029608], dtype=object)

# %%
frame = pd.DataFrame(tcard)
frame.tail(5)
# Out:
#           월별카드매출액
# 기준년월
# 2021/10  53469616
# 2021/11  53827378
# 2021/12  53993508
# 2022/01  54539492
# 2022/02  47029608

# %%
frame.index
# Out:
# Index(['2019/01', '2019/02', '2019/03', '2019/04', '2019/05', '2019/06',
#        '2019/07', '2019/08', '2019/09', '2019/10', '2019/11', '2019/12',
#        '2020/01', '2020/02', '2020/03', '2020/04', '2020/05', '2020/06',
#        '2020/07', '2020/08', '2020/09', '2020/10', '2020/11', '2020/12',
#        '2021/01', '2021/02', '2021/03', '2021/04', '2021/05', '2021/06',
#        '2021/07', '2021/08', '2021/09', '2021/10', '2021/11', '2021/12',
#        '2022/01', '2022/02'],
#       dtype='object', name='기준년월')

# %%
frame.index.names = ['기준년월']
frame.tail(5)
# Out:
#           월별카드매출액
# 기준년월
# 2021/10  53469616
# 2021/11  53827378
# 2021/12  53993508
# 2022/01  54539492
# 2022/02  47029608

# %%
frame = frame.reset_index()
frame
# Out:
#        기준년월   월별카드매출액
# 0   2019/01  44936072
# 1   2019/02  38921767
# 2   2019/03  44496876
# 3   2019/04  43591233
# 4   2019/05  46109266
# 5   2019/06  43594544
# 6   2019/07  46211620
# 7   2019/08  45275053
# 8   2019/09  43921467
# 9   2019/10  46599097
# 10  2019/11  46743092
# 11  2019/12  48407568
# 12  2020/01  47333540
# 13  2020/02  41266091
# 14  2020/03  41916271
# 15  2020/04  43066211
# 16  2020/05  46919475
# 17  2020/06  46392367
# 18  2020/07  47806147
# 19  2020/08  46377231
# 20  2020/09  47128339
# 21  2020/10  47304200
# 22  2020/11  47680752
# 23  2020/12  46881759
# 24  2021/01  46268277
# 25  2021/02  44023439
# 26  2021/03  49869479
# 27  2021/04  48970480
# 28  2021/05  51219562
# 29  2021/06  50209911
# 30  2021/07  52583282
# 31  2021/08  50076065
# 32  2021/09  50710469
# 33  2021/10  53469616
# 34  2021/11  53827378
# 35  2021/12  53993508
# 36  2022/01  54539492
# 37  2022/02  47029608

# %%
frame['기준년월'].str.split('/').tolist()
# Out:
# [['2019', '01'],
#  ['2019', '02'],
#  ['2019', '03'],
#  ['2019', '04'],
#  ['2019', '05'],
#  ['2019', '06'],
#  ['2019', '07'],
#  ['2019', '08'],
#  ['2019', '09'],
#  ['2019', '10'],
#  ['2019', '11'],
#  ['2019', '12'],
#  ['2020', '01'],
#  ['2020', '02'],
#  ['2020', '03'],
#  ['2020', '04'],
#  ['2020', '05'],
#  ['2020', '06'],
#  ['2020', '07'],
#  ['2020', '08'],
#  ['2020', '09'],
#  ['2020', '10'],
#  ['2020', '11'],
#  ['2020', '12'],
#  ['2021', '01'],
#  ['2021', '02'],
#  ['2021', '03'],
#  ['2021', '04'],
#  ['2021', '05'],
#  ['2021', '06'],
#  ['2021', '07'],
#  ['2021', '08'],
#  ['2021', '09'],
#  ['2021', '10'],
#  ['2021', '11'],
#  ['2021', '12'],
#  ['2022', '01'],
#  ['2022', '02']]

# %%
frame1 = pd.DataFrame(frame['기준년월'].str.split('/').tolist(),columns=['year', 'month'])
frame1.head(5)
# Out:
#    year month
# 0  2019    01
# 1  2019    02
# 2  2019    03
# 3  2019    04
# 4  2019    05

# %%
frame2 = pd.concat([frame1, frame], axis = 1)
frame2.head(5)
# Out:
#    year month     기준년월   월별카드매출액
# 0  2019    01  2019/01  44936072
# 1  2019    02  2019/02  38921767
# 2  2019    03  2019/03  44496876
# 3  2019    04  2019/04  43591233
# 4  2019    05  2019/05  46109266

# %%
frame2019 = frame2[frame2['year'] == '2019']
frame2020 = frame2[frame2['year'] == '2020']
frame2021 = frame2[frame2['year'] == '2021']

frame2019
# Out:
#     year month     기준년월   월별카드매출액
# 0   2019    01  2019/01  44936072
# 1   2019    02  2019/02  38921767
# 2   2019    03  2019/03  44496876
# 3   2019    04  2019/04  43591233
# 4   2019    05  2019/05  46109266
# 5   2019    06  2019/06  43594544
# 6   2019    07  2019/07  46211620
# 7   2019    08  2019/08  45275053
# 8   2019    09  2019/09  43921467
# 9   2019    10  2019/10  46599097
# 10  2019    11  2019/11  46743092
# 11  2019    12  2019/12  48407568

# %%
fig = plt.figure(figsize=(16, 8))
sns.set(style="white", context="talk", font="Malgun Gothic")

plt.plot(frame2019['month'], frame2019["월별카드매출액"], label="2019년도")
plt.plot(frame2020['month'], frame2020["월별카드매출액"], label="2020년도")
plt.plot(frame2021['month'], frame2021["월별카드매출액"], label="2021년도")
# plt.rc('font', family='Malgun Gothic')
plt.ylabel("월별개인신용카드승인금액(10조원)")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 fig = plt.figure(figsize=(16, 8))
#       2 sns.set(style="white", context="talk", font="Malgun Gothic")
#       4 plt.plot(frame2019['month'], frame2019["월별카드매출액"], label="2019년도")
#
# NameError: name 'plt' is not defined

# %%
df.head(5)
# Out:
#                             0                         1     \
# 통계표     7.5.2. 지역별 소비유형별 개인 신용카드  7.5.2. 지역별 소비유형별 개인 신용카드
# 지역코드                          전국                        전국
# 소비유형코드                        합계                        합계
# 금액구분코드                        총액                    월간 일평균
# 단위                          백만원                       백만원
#
#                             2                         3     \
# 통계표     7.5.2. 지역별 소비유형별 개인 신용카드  7.5.2. 지역별 소비유형별 개인 신용카드
# 지역코드                          전국                        전국
# 소비유형코드                      종합소매                      종합소매
# 금액구분코드                        총액                    월간 일평균
# 단위                          백만원                       백만원
#
#                             4                         5     \
# 통계표     7.5.2. 지역별 소비유형별 개인 신용카드  7.5.2. 지역별 소비유형별 개인 신용카드
# 지역코드                          전국                        전국
# 소비유형코드                       백화점                       백화점
# 금액구분코드                        총액                    월간 일평균
# 단위                          백만원                       백만원
#
#                             6                         7     \
# 통계표     7.5.2. 지역별 소비유형별 개인 신용카드  7.5.2. 지역별 소비유형별 개인 신용카드
# 지역코드                          전국                        전국
# 소비유형코드                대형마트/유통전문점                대형마트/유통전문점
# 금액구분코드                        총액                    월간 일평균
# 단위                          백만원                       백만원
#
#                             8                         9     ...  \
# 통계표     7.5.2. 지역별 소비유형별 개인 신용카드  7.5.2. 지역별 소비유형별 개인 신용카드  ...
# 지역코드                          전국                        전국  ...
# 소비유형코드                      슈퍼마켓                      슈퍼마켓  ...
# 금액구분코드                        총액                    월간 일평균  ...
# 단위                          백만원                       백만원   ...
#
#                             1466                      1467  \
# 통계표     7.5.2. 지역별 소비유형별 개인 신용카드  7.5.2. 지역별 소비유형별 개인 신용카드
# 지역코드                          기타                        기타
# 소비유형코드                        숙박                        숙박
# 금액구분코드                        총액                    월간 일평균
# 단위                          백만원                       백만원
#
#                             1468                      1469  \
# 통계표     7.5.2. 지역별 소비유형별 개인 신용카드  7.5.2. 지역별 소비유형별 개인 신용카드
# 지역코드                          기타                        기타
# 소비유형코드                       음식점                       음식점
# 금액구분코드                        총액                    월간 일평균
# 단위                          백만원                       백만원
#
#                             1470                      1471  \
# 통계표     7.5.2. 지역별 소비유형별 개인 신용카드  7.5.2. 지역별 소비유형별 개인 신용카드
# 지역코드                          기타                        기타
# 소비유형코드           공과금/개인 및 전문 서비스           공과금/개인 및 전문 서비스
# 금액구분코드                        총액                    월간 일평균
# 단위                          백만원                       백만원
#
#                             1472                      1473  \
# 통계표     7.5.2. 지역별 소비유형별 개인 신용카드  7.5.2. 지역별 소비유형별 개인 신용카드
# 지역코드                          기타                        기타
# 소비유형코드                     금융/보험                     금융/보험
# 금액구분코드                        총액                    월간 일평균
# 단위                          백만원                       백만원
#
#                             1474                      1475
# 통계표     7.5.2. 지역별 소비유형별 개인 신용카드  7.5.2. 지역별 소비유형별 개인 신용카드
# 지역코드                          기타                        기타
# 소비유형코드                        기타                        기타
# 금액구분코드                        총액                    월간 일평균
# 단위                          백만원                       백만원
#
# [5 rows x 1476 columns]

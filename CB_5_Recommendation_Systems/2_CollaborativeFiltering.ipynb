# %% [markdown]
# # Collaborative Filtering: k-Nearest Neighbor

# %% [markdown]
# 먼저 필요한 라이브러리를 설치해야 한다.<br><br>
# 사전 설치가 필요한 Library 리스트<br>
# - pip install pandas: 데이터프레임 처리 라이브러리<br>
# - pip install numpy: array 처리 라이브러리<br>
# - pip install codecs: 파일 불러오기 라이브러리<br>
# - pip install suprise: 추천시스템 모델링 라이브러리<br>

# %% [markdown]
# 분석에 필요한 라이브러리를 불러온다.

# %%
import pandas as pd
import codecs
import surprise
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d3da46af643d> in <module>
#       1 import pandas as pd
#       2 import codecs
# ----> 3 import surprise
#
# ModuleNotFoundError: No module named 'surprise'

# %%
# !pip install surprise

# %% [markdown]
# <br>
#
# # KNN을 활용한 영화 추천

# %% [markdown]
# ## 데이터 처리

# %% [markdown]
# 이 실습에서는 KNN을 활용해 영화를 추천한다.<br><br>
# MovieLens 영화 추천 웹사이트에서 제공하는 평점 데이터를 기반으로 영화 추천을 진행한다.<br>
# 추천에 필요한 평점, 영화 정보를 불러와 데이터프레임을 구성하며, 각 데이터는 아래의 정보를 포함하고 있다.<br>
# - ratings.dat: UserID, MovieID, Rating, Timestamp
# - movies.dat: MovieID, Title, Genres

# %%
ratings_list = [i.strip().split("::") for i in codecs.open('./data/ml-1m/ratings.dat', 'r', encoding='latin').readlines()]
movies_list = [i.strip().split("::") for i in codecs.open('./data/ml-1m/movies.dat', 'r', encoding='latin').readlines()]

# %% [markdown]
# 리스트 형태의 데이터를 데이터프레임 형태로 변환하고, 평점은 string에서 numeric으로 type을 변경해준다.

# %%
ratings_df = pd.DataFrame(ratings_list, columns = ['UserID', 'MovieID', 'Rating', 'Timestamp'], dtype = int)
movies_df = pd.DataFrame(movies_list, columns = ['MovieID', 'Title', 'Genres'])
ratings_df['Rating'] = ratings_df['Rating'].apply(pd.to_numeric)

# %% [markdown]
# 평점 데이터프레임은 다음과 같다.<br>
# 예를 들어 1번 user는 1193번 영화에 평점 5점을 주었다.

# %%
ratings_df.head()
# Out:
#   UserID MovieID  Rating  Timestamp
# 0      1    1193       5  978300760
# 1      1     661       3  978302109
# 2      1     914       3  978301968
# 3      1    3408       4  978300275
# 4      1    2355       5  978824291

# %% [markdown]
# 평점 데이터프레임 중 영화 추천에 불필요한 정보인 Timestamp 열을 삭제해 최종 데이터를 구축한다.

# %%
del ratings_df['Timestamp']
ratings_df.head()
# Out:
#   UserID MovieID  Rating
# 0      1    1193       5
# 1      1     661       3
# 2      1     914       3
# 3      1    3408       4
# 4      1    2355       5

# %% [markdown]
# 영화 데이터프레임은 다음과 같다.

# %%
movies_df.head()
# Out:
#   MovieID                               Title                        Genres
# 0       1                    Toy Story (1995)   Animation|Children's|Comedy
# 1       2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2       3             Grumpier Old Men (1995)                Comedy|Romance
# 3       4            Waiting to Exhale (1995)                  Comedy|Drama
# 4       5  Father of the Bride Part II (1995)                        Comedy

# %% [markdown]
# 추천 시스템 라이브러리 surprise를 사용하기 위해 구축한 ratings_df 데이터프레임을 해당 라이브러리에서 요구하는 input 형태에 맞게 변형한다.<br>
# surprise 라이브러리는 dataset을 인풋으로 받으며, pandas 데이터프레임으로부터 dataset을 로딩하기 위해 Reader object와 load_from_df() method를 사용한다.

# %%
from surprise import Reader
from surprise import Dataset

# %%
reader = Reader(rating_scale=(0, 5))
data = Dataset.load_from_df(ratings_df, reader)

# %% [markdown]
# <br>
#
# ## KNN 모델링

# %% [markdown]
# KNN 모델링에 필요한 라이브러리를 불러온다.

# %%
from surprise import KNNBasic
from surprise.model_selection import cross_validate
from surprise import accuracy

# %% [markdown]
# <br>
#
# KNN에서 user 벡터 (평점 행렬의 행 벡터)나 item 벡터 (평점 행렬의 열 벡터)의 유사도를 비교하기 위해 다양한 지표를 사용할 수 있다.<br>
# suprise.KNNBasic 함수에서는 아래와 같은 유사도 기준을 제공하며, 본 강의에서는 유클리드 거리와 코사인 유사도를 중심으로 분석을 진행한다.<br>
# - 유클리드 거리 기반 유사도 (Mean Squared Difference Similarity)
# - 코사인 유사도 (Cosine Similarity)
# - 피어슨 유사도 (Pearson Similarity)
# - 피어슨-베이스라인 유사도 (Pearson-Baseline Similarity)

# %% [markdown]
# surprise.KNNBasic 패키지의 유사도 설정 옵션은 다음과 같다.<br>
# - name: 사용할 유사도의 종류. ['msd', 'cosine', 'pearson', 'pearson_baseline'] 중 선택.
# - user_based: True면 사용자 기반, False면 상품 기반.
# - min_support: 두 사용자나, 상품에서 공통적으로 있는 평점 원소의 수의 최솟값. 공통 평점 원소의 수가 이 값보다 적으면 해당 벡터는 사용하지 않는다. 디폴트는 1.
# - shrinkage: Shrinkage 가중치. 디폴트는 100.

# %% [markdown]
# KNN의 user/item 기반, 유클리드거리/코사인유사도 옵션의 조합을 이용해 아래와 같이 4가지 옵션 리스트를 생성한다.

# %%
sim_options = [{'name': 'msd', 'user_based': True},
               {'name': 'cosine', 'user_based': True},
               {'name': 'msd', 'user_based': False},
               {'name': 'cosine', 'user_based': False}]

# %% [markdown]
# 위에서 생성한 4가지 옵션 리스트를 기반으로 4가지 모델을 만들고 cross-validation 결과를 통해 가장 성능이 좋은 모델을 선택한다.

# %%
def model_selection(sim_options):
    perf = []
    # iterate over all algorithms
    for i, sim_option in enumerate(sim_options):
        print('==> ', i, '번째 모델 학습을 시작합니다.')
        
        # make KNN model for each option
        algo = KNNBasic(sim_options=sim_option)

        # perform cross validation
        results = cross_validate(algo, data, measures=['RMSE'], cv=3, verbose=False)

        # get results
        tmp = pd.DataFrame.from_dict(results).mean(axis=0)
        tmp = tmp.append(pd.Series([sim_option['name'], sim_option['user_based']], index=['metric', 'user_based']))
        perf.append(tmp)

    model_selection_results = pd.DataFrame(perf).set_index(['metric', 'user_based']).sort_values('test_rmse')
    return model_selection_results

# %%
model_selection_results = model_selection(sim_options)
# Out:
# ==>  0 번째 모델 학습을 시작합니다.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ==>  1 번째 모델 학습을 시작합니다.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# ==>  2 번째 모델 학습을 시작합니다.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ==>  3 번째 모델 학습을 시작합니다.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %%
model_selection_results
# Out:
#                    test_rmse   fit_time   test_time
# metric user_based
# msd    False        0.925074   7.089707   72.232902
#        True         0.930937  22.562656  146.383257
# cosine True         0.979274  46.451010  146.975886
#        False        1.003462  14.945996   72.855004

# %% [markdown]
# <br>
#
# ## 최적 KNN 모델 분석

# %% [markdown]
# 위에서 실험한 4가지 모델 중 test 데이터에 대한 rmse 값을 기준으로 유클리드 거리를 사용한 item 기반 KNN 알고리즘이 가장 좋은 결과를 도출했다.<br>
# 따라서 해당 알고리즘을 이용해 보다 자세한 결과를 확인하기 위해 데이터를 7:3의 비율로 train과 test 데이터로 분할한다.

# %%
from surprise.model_selection import train_test_split

trainset, testset = train_test_split(data, test_size=0.3, random_state=42)

# %% [markdown]
# 앞서 model selection에서 선택된 유클리드 거리를 사용한 item 기반 KNN 알고리즘을 구축하고 해당 모델을 train 데이터로 학습한다.

# %%
sim_option = {'name': 'msd', 'user_based':False}
model_knn = KNNBasic(sim_options=sim_option)
model_knn.fit(trainset)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %% [markdown]
# train 데이터로 학습한 KNN 알고리즘을 기반으로 test 데이터의 평점을 예측한다.

# %%
preds = model_knn.test(testset)
preds
# Out:
# [Prediction(uid='3718', iid='1234', r_ui=3.0, est=3.762350718741624, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4048', iid='1937', r_ui=5.0, est=4.077290640722361, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5074', iid='1458', r_ui=1.0, est=3.0832951945080094, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5502', iid='608', r_ui=4.0, est=3.965104242805639, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1903', iid='596', r_ui=4.0, est=3.9736913763297936, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1116', iid='1220', r_ui=4.0, est=4.146668824382584, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='646', iid='2406', r_ui=5.0, est=3.946848744435971, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4972', iid='1994', r_ui=3.0, est=4.046743159222435, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='699', iid='1453', r_ui=2.0, est=2.381280967835205, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3945', iid='1676', r_ui=3.0, est=2.775345090549015, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1976', iid='3510', r_ui=5.0, est=4.218919301506484, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3327', iid='1921', r_ui=4.0, est=3.9924856294965396, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2781', iid='2348', r_ui=5.0, est=4.284314361323424, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='753', iid='3565', r_ui=4.0, est=3.705294529050928, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5986', iid='82', r_ui=5.0, est=4.580586578517311, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4928', iid='1171', r_ui=2.0, est=3.1541605058681386, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='971', iid='2396', r_ui=4.0, est=3.882268863936825, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4584', iid='910', r_ui=5.0, est=4.677693536569921, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4879', iid='1131', r_ui=5.0, est=4.287205885693002, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='516', iid='933', r_ui=3.0, est=3.416399211569992, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4788', iid='2779', r_ui=4.0, est=3.4696362923994997, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5449', iid='2395', r_ui=4.0, est=4.195386484528993, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='308', iid='1682', r_ui=4.0, est=3.701311860512888, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='975', iid='1234', r_ui=4.0, est=3.947810525813013, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4212', iid='1927', r_ui=4.0, est=4.259757557386975, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='18', iid='1197', r_ui=5.0, est=4.51391281439338, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5277', iid='1220', r_ui=4.0, est=3.603615428383036, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2124', iid='2159', r_ui=5.0, est=4.3332732538376915, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4319', iid='3206', r_ui=4.0, est=3.9506715007662017, details={'actual_k': 33, 'was_impossible': False}),
#  Prediction(uid='4083', iid='1028', r_ui=3.0, est=3.4973869161868567, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3411', iid='2959', r_ui=5.0, est=3.775583564080769, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='531', iid='231', r_ui=3.0, est=3.0681446147929963, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2916', iid='164', r_ui=3.0, est=3.8287577875036956, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1902', iid='1841', r_ui=3.0, est=3.18715947425704, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3318', iid='1358', r_ui=4.0, est=4.351673990341618, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='329', iid='355', r_ui=2.0, est=1.8105641682169704, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='6022', iid='1200', r_ui=4.0, est=3.9052599741175413, details={'actual_k': 37, 'was_impossible': False}),
#  Prediction(uid='5341', iid='2020', r_ui=4.0, est=4.0458645498308625, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1228', iid='2318', r_ui=3.0, est=4.051296139981438, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='752', iid='1747', r_ui=5.0, est=3.0701581175295445, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='275', iid='1090', r_ui=5.0, est=4.498148038449376, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='92', iid='709', r_ui=3.0, est=2.4653223910182147, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3266', iid='1545', r_ui=5.0, est=4.5827392039588455, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='161', iid='2858', r_ui=5.0, est=4.575932034474745, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5539', iid='551', r_ui=3.0, est=4.103021332737207, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5345', iid='3361', r_ui=4.0, est=4.153156489130132, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4212', iid='3792', r_ui=4.0, est=3.570207866948956, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4562', iid='1982', r_ui=1.0, est=3.465385572256655, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2403', iid='924', r_ui=3.0, est=3.842628774794819, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1748', iid='733', r_ui=4.0, est=3.416229089980378, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4042', iid='3723', r_ui=3.0, est=3.719652208677868, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3108', iid='349', r_ui=4.0, est=3.6718431134041145, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2472', iid='555', r_ui=3.0, est=3.9378973081953648, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='888', iid='2028', r_ui=3.0, est=3.990543357505869, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4917', iid='265', r_ui=2.0, est=3.64184479256331, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='516', iid='968', r_ui=2.0, est=3.0504357730303475, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2683', iid='1676', r_ui=4.0, est=4.379557250975767, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5531', iid='1275', r_ui=5.0, est=3.950299188633619, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3377', iid='861', r_ui=5.0, est=3.969145576411834, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3878', iid='1968', r_ui=4.0, est=4.22900756516304, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2411', iid='1544', r_ui=3.0, est=2.962440673938977, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5486', iid='555', r_ui=4.0, est=4.179687009505112, details={'actual_k': 35, 'was_impossible': False}),
#  Prediction(uid='5196', iid='1411', r_ui=4.0, est=3.534565645640906, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5720', iid='3448', r_ui=1.0, est=2.8514569977043087, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='151', iid='318', r_ui=3.0, est=4.119722976563507, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1943', iid='1991', r_ui=4.0, est=3.0545880964650642, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3935', iid='3735', r_ui=4.0, est=3.637781278044846, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3056', iid='3764', r_ui=3.0, est=3.245344384984678, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2089', iid='608', r_ui=4.0, est=4.1019547230017865, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2993', iid='1206', r_ui=4.0, est=4.182366293395423, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='958', iid='356', r_ui=4.0, est=3.982888560946665, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5454', iid='296', r_ui=5.0, est=4.31237606555788, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5537', iid='1250', r_ui=5.0, est=4.389700209017674, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1714', iid='2349', r_ui=4.0, est=3.5234313614813626, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4591', iid='2530', r_ui=4.0, est=2.910753100112805, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='442', iid='420', r_ui=3.0, est=2.573188995169705, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5785', iid='2268', r_ui=4.0, est=4.550807191091969, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='631', iid='3543', r_ui=3.0, est=3.9443560442577255, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3568', iid='1233', r_ui=5.0, est=4.206809600444227, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2342', iid='307', r_ui=4.0, est=3.8783809815076573, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='746', iid='353', r_ui=2.0, est=2.830557316106397, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1941', iid='1515', r_ui=3.0, est=3.0952055316701017, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4521', iid='926', r_ui=5.0, est=4.506956299401603, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4950', iid='3301', r_ui=3.0, est=3.354077555546013, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1170', iid='1542', r_ui=4.0, est=3.786259889409373, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1760', iid='368', r_ui=2.0, est=3.7389959176019003, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5337', iid='934', r_ui=4.0, est=4.394375071838088, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='996', iid='517', r_ui=3.0, est=3.58590085685601, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5811', iid='640', r_ui=4.0, est=3.26198985534852, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3411', iid='1204', r_ui=3.0, est=3.8514175007725857, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5113', iid='2410', r_ui=1.0, est=1.7308163303403066, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2223', iid='1343', r_ui=3.0, est=2.8725156521761663, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2164', iid='3917', r_ui=4.0, est=3.6591035574190007, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3842', iid='3627', r_ui=5.0, est=4.041397763533408, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1692', iid='1387', r_ui=5.0, est=4.461792131763278, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4193', iid='3358', r_ui=3.0, est=3.427479500823101, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4799', iid='11', r_ui=5.0, est=3.73483131798866, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5938', iid='3911', r_ui=5.0, est=4.383079680158117, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2271', iid='1204', r_ui=5.0, est=4.671518053046084, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2507', iid='1171', r_ui=4.0, est=4.039424447004092, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2994', iid='3703', r_ui=3.0, est=3.6491767046870107, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='314', iid='3730', r_ui=5.0, est=3.969586510741852, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4808', iid='1345', r_ui=4.0, est=3.36399807922494, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2918', iid='1129', r_ui=4.0, est=3.756331217766122, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3625', iid='1408', r_ui=5.0, est=3.7858282655336657, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5958', iid='1233', r_ui=4.0, est=3.9126895892355362, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5707', iid='1449', r_ui=5.0, est=4.455941664466193, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1084', iid='3147', r_ui=4.0, est=3.5583446568107844, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1329', iid='3827', r_ui=4.0, est=3.494403629842374, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2309', iid='2331', r_ui=3.0, est=3.4540487905526556, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1522', iid='2640', r_ui=3.0, est=3.573572028960622, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4765', iid='3182', r_ui=5.0, est=4.078192667843588, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1150', iid='22', r_ui=3.0, est=2.653103494556033, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2015', iid='2490', r_ui=5.0, est=2.71990195818497, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1354', iid='353', r_ui=5.0, est=3.2543069995184233, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='199', iid='1259', r_ui=5.0, est=3.792242341236232, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1449', iid='2476', r_ui=2.0, est=2.969043221853521, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2305', iid='2861', r_ui=2.0, est=3.1278962993214794, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1300', iid='2719', r_ui=2.0, est=2.748483746054338, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1912', iid='2003', r_ui=3.0, est=2.49016169443661, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5555', iid='1556', r_ui=3.0, est=1.6713874646115867, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2172', iid='1394', r_ui=5.0, est=3.849171434082211, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4356', iid='950', r_ui=3.0, est=3.9305762768194654, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5608', iid='3317', r_ui=4.0, est=3.7802409474231853, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='5794', iid='1188', r_ui=5.0, est=4.584627379026707, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5824', iid='2763', r_ui=3.0, est=3.357909427953845, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3850', iid='3773', r_ui=2.0, est=3.8573518419342143, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='150', iid='1294', r_ui=5.0, est=4.301919286849031, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1727', iid='946', r_ui=5.0, est=4.20495683032399, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4585', iid='1580', r_ui=4.0, est=3.9261773437426273, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1999', iid='904', r_ui=4.0, est=3.9185491354936497, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2872', iid='2605', r_ui=3.0, est=2.9711287567127638, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5136', iid='1394', r_ui=1.0, est=3.9272655576572166, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5108', iid='1440', r_ui=4.0, est=2.765143159511404, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3732', iid='1294', r_ui=4.0, est=3.795650966693631, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3308', iid='2145', r_ui=5.0, est=3.105066633041093, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3497', iid='2724', r_ui=3.0, est=4.086050140455323, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4115', iid='3071', r_ui=4.0, est=3.960534818945656, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='673', iid='1416', r_ui=1.0, est=3.6176144957513507, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3415', iid='224', r_ui=3.0, est=3.89705895864455, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1758', iid='21', r_ui=4.0, est=4.349271970239656, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4910', iid='3174', r_ui=5.0, est=3.58143267684712, details={'actual_k': 35, 'was_impossible': False}),
#  Prediction(uid='5492', iid='1088', r_ui=2.0, est=2.873290320189981, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='889', iid='2475', r_ui=3.0, est=2.5526547238809427, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4000', iid='3438', r_ui=2.0, est=3.6980974045048276, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5138', iid='165', r_ui=2.0, est=3.1399129304755613, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4285', iid='3258', r_ui=3.0, est=3.56736866955623, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2544', iid='951', r_ui=5.0, est=4.188185001186415, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5600', iid='1885', r_ui=4.0, est=4.164192275646515, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3892', iid='1184', r_ui=3.0, est=3.238998689237378, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='411', iid='2423', r_ui=2.0, est=3.1492279317543916, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2701', iid='3020', r_ui=5.0, est=3.5776850502184434, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3997', iid='1551', r_ui=3.0, est=2.9732116594861235, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5959', iid='1784', r_ui=4.0, est=2.8589674293674836, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='660', iid='1950', r_ui=5.0, est=3.5785810140720224, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1628', iid='2433', r_ui=2.0, est=3.375865784037944, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5271', iid='3529', r_ui=4.0, est=3.1721161896024217, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3305', iid='2890', r_ui=5.0, est=4.366221736848727, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='444', iid='1269', r_ui=4.0, est=4.127276121340464, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1617', iid='1060', r_ui=2.0, est=3.805906735497091, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1418', iid='153', r_ui=4.0, est=2.60477547530738, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='6010', iid='1262', r_ui=5.0, est=4.404542568031276, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5827', iid='761', r_ui=5.0, est=3.538296056820644, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5982', iid='3114', r_ui=3.0, est=4.15675472300415, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='424', iid='1127', r_ui=4.0, est=3.770448632258913, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3510', iid='2916', r_ui=3.0, est=3.8619089422886796, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1150', iid='1614', r_ui=2.0, est=2.6103792501624903, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4447', iid='1066', r_ui=4.0, est=3.4532681876327276, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3821', iid='2628', r_ui=2.0, est=2.3523098778509057, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3425', iid='2917', r_ui=3.0, est=4.130857273569985, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4831', iid='2312', r_ui=5.0, est=4.051896054588239, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5567', iid='1179', r_ui=2.0, est=3.64263018853453, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2921', iid='3698', r_ui=2.0, est=3.1494290207486193, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2935', iid='1129', r_ui=4.0, est=3.6943347315692376, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5472', iid='2819', r_ui=3.0, est=3.164338113158694, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1842', iid='3203', r_ui=4.0, est=4.319104778927474, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5219', iid='95', r_ui=2.0, est=3.6702708006649214, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3024', iid='196', r_ui=4.0, est=3.484305487889281, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='9', iid='349', r_ui=4.0, est=3.798786303540089, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1757', iid='1206', r_ui=5.0, est=4.707342019778429, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3940', iid='3499', r_ui=3.0, est=4.011791751329875, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1015', iid='648', r_ui=3.0, est=3.3433846151638624, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4258', iid='1805', r_ui=3.0, est=3.577408605102473, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1017', iid='2657', r_ui=5.0, est=3.10307449034777, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2378', iid='2329', r_ui=5.0, est=3.8504198228677007, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4508', iid='2549', r_ui=1.0, est=2.863304079443009, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4389', iid='2248', r_ui=4.0, est=3.781736797859063, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='346', iid='3606', r_ui=5.0, est=4.524669052190655, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5062', iid='3629', r_ui=5.0, est=4.0512731471737276, details={'actual_k': 14, 'was_impossible': False}),
#  Prediction(uid='3285', iid='2076', r_ui=3.0, est=3.8959958819777656, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5030', iid='223', r_ui=4.0, est=3.973224021584392, details={'actual_k': 18, 'was_impossible': False}),
#  Prediction(uid='3304', iid='1084', r_ui=5.0, est=4.328132149891473, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4834', iid='3037', r_ui=4.0, est=3.8412963179479007, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5717', iid='2398', r_ui=3.0, est=3.6662705458853173, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3401', iid='2396', r_ui=4.0, est=3.775724259342244, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4680', iid='1230', r_ui=5.0, est=4.1801979231352595, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2695', iid='1028', r_ui=4.0, est=3.9860839240906625, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2947', iid='2318', r_ui=2.0, est=3.915435636675662, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='391', iid='3508', r_ui=5.0, est=4.197254626227683, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1750', iid='3354', r_ui=1.0, est=2.9348764645106744, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1745', iid='2490', r_ui=4.0, est=3.862576319239837, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2289', iid='1270', r_ui=5.0, est=4.037435311816261, details={'actual_k': 24, 'was_impossible': False}),
#  Prediction(uid='5011', iid='2020', r_ui=4.0, est=4.021432160765474, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='655', iid='3461', r_ui=4.0, est=2.9892258650101793, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5445', iid='34', r_ui=5.0, est=3.977254544421724, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='639', iid='1073', r_ui=2.0, est=3.7521666096426305, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5321', iid='1135', r_ui=3.0, est=2.8094336525828894, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1096', iid='413', r_ui=1.0, est=2.2361592706997877, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='354', iid='2710', r_ui=4.0, est=3.503510239604238, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2814', iid='3408', r_ui=5.0, est=4.334469397691569, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5888', iid='2265', r_ui=2.0, est=1.5029530858617934, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4105', iid='2806', r_ui=3.0, est=2.5911927925220652, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1632', iid='3076', r_ui=3.0, est=2.7775807452304826, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='752', iid='209', r_ui=2.0, est=2.6535980578687948, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2063', iid='1754', r_ui=5.0, est=2.764330745235915, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1146', iid='2428', r_ui=3.0, est=2.272258025616677, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1941', iid='2875', r_ui=3.0, est=3.030598622160097, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1979', iid='3354', r_ui=3.0, est=2.9848776435175846, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='5268', iid='3190', r_ui=1.0, est=1.8613986940810054, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2235', iid='2572', r_ui=4.0, est=3.650512142038308, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='6000', iid='2918', r_ui=4.0, est=3.9069487959320455, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4849', iid='362', r_ui=4.0, est=3.9503425638445684, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1896', iid='1945', r_ui=5.0, est=4.204244704469443, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3504', iid='1358', r_ui=2.0, est=3.652586772603015, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='819', iid='296', r_ui=5.0, est=3.5897640947714855, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1624', iid='1573', r_ui=5.0, est=3.173129394984813, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2281', iid='2762', r_ui=4.0, est=4.174008688428811, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5824', iid='1259', r_ui=4.0, est=3.8515162992140013, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3428', iid='2712', r_ui=2.0, est=3.907515369823644, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2473', iid='3869', r_ui=3.0, est=3.869362235700076, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='5002', iid='1370', r_ui=4.0, est=3.244629517092797, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='924', iid='17', r_ui=3.0, est=3.968728092847419, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4411', iid='260', r_ui=5.0, est=4.736921221292671, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5256', iid='196', r_ui=2.0, est=2.9137358874711943, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3391', iid='2108', r_ui=5.0, est=3.988641444304866, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1774', iid='1971', r_ui=4.0, est=3.1758463664101404, details={'actual_k': 30, 'was_impossible': False}),
#  Prediction(uid='3065', iid='605', r_ui=3.0, est=3.6288762497928646, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2409', iid='3039', r_ui=4.0, est=3.8738555734246205, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2664', iid='1393', r_ui=4.0, est=3.8083052118410876, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='6001', iid='2950', r_ui=2.0, est=2.914217738429195, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2724', iid='1672', r_ui=5.0, est=3.4397300828471327, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2810', iid='2002', r_ui=3.0, est=3.596354756482304, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2250', iid='3798', r_ui=4.0, est=2.8379725674906466, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4745', iid='1873', r_ui=1.0, est=4.206793615855222, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4083', iid='2396', r_ui=3.0, est=3.808953996198034, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5623', iid='1305', r_ui=4.0, est=3.8351972831278145, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='53', iid='372', r_ui=2.0, est=4.020636424830443, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2860', iid='936', r_ui=5.0, est=4.235294561048042, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1495', iid='745', r_ui=5.0, est=3.679620640736797, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5553', iid='296', r_ui=4.0, est=4.143970252624496, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4018', iid='3654', r_ui=5.0, est=3.8731160550562285, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4467', iid='781', r_ui=3.0, est=3.4677899753542327, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4480', iid='2598', r_ui=2.0, est=2.042741600112263, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5722', iid='2789', r_ui=1.0, est=2.48576784987297, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4478', iid='1176', r_ui=4.0, est=3.123500664702399, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3689', iid='474', r_ui=4.0, est=3.299150900400182, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4345', iid='1682', r_ui=4.0, est=3.7377634748316373, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5652', iid='2028', r_ui=5.0, est=4.018525222718612, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4915', iid='2428', r_ui=2.0, est=3.022515826274189, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5686', iid='196', r_ui=2.0, est=1.6036336699192204, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5675', iid='1632', r_ui=4.0, est=3.4530892448512613, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2456', iid='2125', r_ui=3.0, est=3.2003672670755225, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1879', iid='589', r_ui=5.0, est=4.2295888950771445, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2559', iid='2115', r_ui=4.0, est=4.029239795435042, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='869', iid='2166', r_ui=3.0, est=3.2258829433996494, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4609', iid='3013', r_ui=2.0, est=2.898306675677201, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3067', iid='3861', r_ui=3.0, est=3.6918203307006667, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2590', iid='849', r_ui=3.0, est=2.334255715788365, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3929', iid='367', r_ui=2.0, est=2.9318863769284453, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3924', iid='1131', r_ui=4.0, est=4.171731716140948, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4482', iid='2243', r_ui=4.0, est=4.144411727721097, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4067', iid='3408', r_ui=3.0, est=3.552236144188421, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3158', iid='2174', r_ui=4.0, est=4.222647193838836, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3081', iid='1960', r_ui=5.0, est=4.389407424479186, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3013', iid='2961', r_ui=3.0, est=3.195674936677551, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3829', iid='1732', r_ui=1.0, est=3.1112955790664882, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3825', iid='2513', r_ui=3.0, est=2.2603845590949048, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1727', iid='587', r_ui=4.0, est=3.942649954318191, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5779', iid='1194', r_ui=2.0, est=3.3619940908974524, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1377', iid='419', r_ui=2.0, est=2.0928561932300096, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2862', iid='2946', r_ui=4.0, est=3.839790908688064, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1058', iid='1376', r_ui=4.0, est=3.7695746512277095, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2224', iid='32', r_ui=4.0, est=4.360013756497882, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='3273', iid='924', r_ui=5.0, est=4.055755879522608, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='3807', iid='1129', r_ui=5.0, est=3.6994270119635075, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4253', iid='3108', r_ui=2.0, est=3.2580100407286112, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3401', iid='1135', r_ui=2.0, est=2.8419880722313007, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3281', iid='356', r_ui=5.0, est=4.279727216574573, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2820', iid='480', r_ui=1.0, est=2.639205083621633, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1323', iid='1290', r_ui=3.0, est=3.383528096736014, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='310', iid='480', r_ui=3.0, est=3.486218662405622, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='13', iid='318', r_ui=4.0, est=3.774562537358137, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='851', iid='3160', r_ui=5.0, est=3.6923768661335794, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5430', iid='2906', r_ui=5.0, est=2.938476441252301, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4238', iid='2255', r_ui=4.0, est=2.7386198211227226, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2063', iid='2713', r_ui=3.0, est=2.5506541724192315, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='255', iid='2699', r_ui=4.0, est=3.9641050739577137, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4157', iid='1587', r_ui=3.0, est=3.1319195730803955, details={'actual_k': 37, 'was_impossible': False}),
#  Prediction(uid='1974', iid='356', r_ui=2.0, est=3.867123241052723, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5131', iid='2081', r_ui=4.0, est=3.6410358387273796, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2411', iid='1269', r_ui=3.0, est=4.0359580496112875, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2913', iid='3723', r_ui=3.0, est=3.6239759565579392, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1676', iid='410', r_ui=3.0, est=3.1087922072706844, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1489', iid='2394', r_ui=1.0, est=2.2773678299180427, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='42', iid='1101', r_ui=4.0, est=3.698814979062157, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2484', iid='3210', r_ui=3.0, est=3.437249584305433, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2110', iid='2160', r_ui=3.0, est=3.2648274603250984, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4425', iid='2294', r_ui=3.0, est=3.258993361653168, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5634', iid='442', r_ui=4.0, est=3.750640452218155, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5872', iid='2826', r_ui=5.0, est=3.15375033307307, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5593', iid='2863', r_ui=4.0, est=4.378399653644829, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4150', iid='1426', r_ui=2.0, est=3.31246967491509, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1019', iid='916', r_ui=4.0, est=3.3174158567655807, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3757', iid='1422', r_ui=5.0, est=4.050658715952434, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3430', iid='1199', r_ui=4.0, est=3.6038955126607224, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1873', iid='1080', r_ui=4.0, est=3.626661223575188, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2529', iid='2470', r_ui=4.0, est=3.8666270665932876, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5988', iid='292', r_ui=3.0, est=3.0505776755306524, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5273', iid='3700', r_ui=5.0, est=4.092497356952197, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3576', iid='2352', r_ui=4.0, est=3.4631464155860936, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2077', iid='1835', r_ui=3.0, est=2.7618414036486456, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1364', iid='1189', r_ui=5.0, est=3.9095590383267895, details={'actual_k': 33, 'was_impossible': False}),
#  Prediction(uid='4344', iid='3070', r_ui=4.0, est=3.1516949477918015, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4387', iid='169', r_ui=1.0, est=2.363525698105421, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4048', iid='2142', r_ui=5.0, est=3.9382653174510818, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='156', iid='930', r_ui=4.0, est=4.320541534441769, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1897', iid='2761', r_ui=4.0, est=3.625727554780374, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1285', iid='987', r_ui=3.0, est=3.6662782228696287, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='264', iid='296', r_ui=1.0, est=3.130367456526516, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5131', iid='1779', r_ui=3.0, est=2.6647307694938522, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4673', iid='1393', r_ui=5.0, est=4.238289378772501, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1992', iid='2891', r_ui=4.0, est=2.7985539784745392, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4681', iid='1635', r_ui=2.0, est=3.9806291287524953, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2915', iid='1291', r_ui=5.0, est=3.9953341965845395, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5824', iid='1459', r_ui=3.0, est=3.2283229850044908, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1164', iid='3125', r_ui=2.0, est=3.4476066098799203, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2895', iid='2997', r_ui=5.0, est=4.489745466651301, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5077', iid='176', r_ui=3.0, est=3.928128947473917, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5323', iid='2289', r_ui=5.0, est=4.272637044597506, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3085', iid='1387', r_ui=4.0, est=4.428885872062649, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2944', iid='2828', r_ui=3.0, est=3.759058367273709, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1035', iid='3160', r_ui=5.0, est=3.93826592277542, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1235', iid='1393', r_ui=5.0, est=3.681418336425555, details={'actual_k': 35, 'was_impossible': False}),
#  Prediction(uid='4481', iid='736', r_ui=4.0, est=3.148687273737436, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4064', iid='2247', r_ui=2.0, est=2.8707324053930883, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1698', iid='589', r_ui=5.0, est=4.184351094117157, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5812', iid='3787', r_ui=4.0, est=3.55, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4115', iid='2987', r_ui=5.0, est=4.206606584173384, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3630', iid='356', r_ui=4.0, est=3.765705914820102, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4103', iid='296', r_ui=3.0, est=3.926275147553781, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='407', iid='296', r_ui=5.0, est=3.9077246427406083, details={'actual_k': 21, 'was_impossible': False}),
#  Prediction(uid='2171', iid='3224', r_ui=5.0, est=4.4921241601127475, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1168', iid='1593', r_ui=3.0, est=3.0040273386692364, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5387', iid='1357', r_ui=4.0, est=3.824326505193598, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='438', iid='2053', r_ui=2.0, est=2.2279868711164523, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2327', iid='780', r_ui=4.0, est=3.4822122184772812, details={'actual_k': 38, 'was_impossible': False}),
#  Prediction(uid='1044', iid='1374', r_ui=5.0, est=3.7750617453895305, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2962', iid='3753', r_ui=3.0, est=2.829437490012646, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4852', iid='1242', r_ui=4.0, est=3.957738180932129, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4169', iid='2467', r_ui=3.0, est=3.4489092657301654, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='398', iid='2628', r_ui=3.0, est=3.221200115510829, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1835', iid='3525', r_ui=4.0, est=3.824238227508536, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2837', iid='348', r_ui=4.0, est=3.3589699336981003, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4051', iid='2114', r_ui=3.0, est=2.981442162202451, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1658', iid='3424', r_ui=4.0, est=3.4651615772440456, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1019', iid='1206', r_ui=5.0, est=3.6835999929628755, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4748', iid='3102', r_ui=5.0, est=4.180743551383407, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1521', iid='3897', r_ui=4.0, est=3.5980463177752, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1851', iid='190', r_ui=1.0, est=2.719451464315913, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='150', iid='595', r_ui=4.0, est=4.202930615248317, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5900', iid='1271', r_ui=3.0, est=2.9527868577281136, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1062', iid='1289', r_ui=5.0, est=4.584923685256858, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4605', iid='1287', r_ui=5.0, est=3.3623001823667344, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2016', iid='2985', r_ui=4.0, est=4.059494847715172, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5952', iid='942', r_ui=4.0, est=4.572081352372587, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2168', iid='538', r_ui=5.0, est=3.953555930848376, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2378', iid='39', r_ui=2.0, est=3.4596640456210945, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1413', iid='919', r_ui=2.0, est=4.2566420156249, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2251', iid='1057', r_ui=3.0, est=3.942966829426049, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1509', iid='256', r_ui=2.0, est=2.367407317301, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='24', iid='1633', r_ui=4.0, est=3.9845206837445177, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5511', iid='923', r_ui=5.0, est=4.603297764115791, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5595', iid='382', r_ui=3.0, est=2.6251406778080346, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4626', iid='2384', r_ui=3.0, est=3.6128152552366144, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1260', iid='2987', r_ui=4.0, est=3.7924773362304416, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2416', iid='3623', r_ui=3.0, est=3.7441307118889053, details={'actual_k': 33, 'was_impossible': False}),
#  Prediction(uid='5749', iid='3163', r_ui=5.0, est=3.9142292248164425, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2938', iid='2020', r_ui=4.0, est=4.081124542987193, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5213', iid='3484', r_ui=2.0, est=3.2364104284955832, details={'actual_k': 18, 'was_impossible': False}),
#  Prediction(uid='3140', iid='3702', r_ui=3.0, est=4.063211919074037, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1859', iid='2028', r_ui=3.0, est=3.7228693299685265, details={'actual_k': 32, 'was_impossible': False}),
#  Prediction(uid='2544', iid='3727', r_ui=4.0, est=3.5766521990763342, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5788', iid='2858', r_ui=5.0, est=4.4631336949056095, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1523', iid='1214', r_ui=4.0, est=4.004673858181421, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2348', iid='32', r_ui=3.0, est=2.9626136633762683, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2172', iid='593', r_ui=4.0, est=3.935674347365129, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='793', iid='1220', r_ui=2.0, est=3.193495825042474, details={'actual_k': 40, 'was_impossible': False}),
# ...
#  Prediction(uid='300', iid='552', r_ui=3.0, est=4.026182257179587, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='199', iid='457', r_ui=4.0, est=3.718927045861027, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3261', iid='1281', r_ui=5.0, est=3.1286253398088872, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3400', iid='165', r_ui=4.0, est=3.9994710026621982, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1391', iid='294', r_ui=4.0, est=3.225788222656824, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3419', iid='1704', r_ui=5.0, est=4.160753660162415, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4279', iid='2006', r_ui=2.0, est=3.279651374093328, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5131', iid='534', r_ui=4.0, est=3.3674684224898073, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1587', iid='1954', r_ui=4.0, est=3.797090775506841, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4312', iid='1884', r_ui=5.0, est=3.601595807390691, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5292', iid='3471', r_ui=2.0, est=3.604561991938776, details={'actual_k': 19, 'was_impossible': False}),
#  Prediction(uid='3469', iid='1339', r_ui=3.0, est=3.4270380181549465, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5431', iid='1693', r_ui=4.0, est=3.904190964307081, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2121', iid='3548', r_ui=3.0, est=3.59973801480451, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5148', iid='377', r_ui=4.0, est=3.758623595562759, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1375', iid='237', r_ui=4.0, est=3.685064900684652, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4204', iid='2355', r_ui=4.0, est=4.502607858493664, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1929', iid='3285', r_ui=1.0, est=3.2259983434273494, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='3539', iid='1517', r_ui=4.0, est=3.970347643670114, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5038', iid='1224', r_ui=4.0, est=3.916813431825406, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2479', iid='1197', r_ui=5.0, est=3.9375279725926786, details={'actual_k': 27, 'was_impossible': False}),
#  Prediction(uid='4560', iid='628', r_ui=3.0, est=3.593659317529003, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='810', iid='2599', r_ui=3.0, est=4.272712080570944, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5458', iid='2024', r_ui=4.0, est=3.7759297993191385, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4109', iid='3703', r_ui=5.0, est=3.134010578820291, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='4345', iid='1177', r_ui=4.0, est=3.707307491484449, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5086', iid='1250', r_ui=4.0, est=4.277356256076182, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4048', iid='371', r_ui=4.0, est=3.919122854771371, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2609', iid='2028', r_ui=5.0, est=4.490035101735374, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='598', iid='3753', r_ui=4.0, est=3.1688594797349374, details={'actual_k': 27, 'was_impossible': False}),
#  Prediction(uid='6002', iid='3198', r_ui=5.0, est=4.401534628158575, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3308', iid='1080', r_ui=3.0, est=3.8508845137334546, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2565', iid='3785', r_ui=3.0, est=3.457584295036235, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4167', iid='1304', r_ui=4.0, est=4.133060407476902, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3059', iid='1387', r_ui=3.0, est=3.9994902361555846, details={'actual_k': 32, 'was_impossible': False}),
#  Prediction(uid='3626', iid='2700', r_ui=3.0, est=3.6552187043941196, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3834', iid='1947', r_ui=3.0, est=4.296361163095084, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5077', iid='3171', r_ui=4.0, est=3.456512332323669, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2503', iid='3550', r_ui=4.0, est=2.8266298789198014, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5556', iid='58', r_ui=5.0, est=3.6040172336742717, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4829', iid='2294', r_ui=4.0, est=3.7871044138254497, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2380', iid='24', r_ui=4.0, est=3.0729015965968793, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1010', iid='2978', r_ui=3.0, est=2.038057858073523, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3278', iid='1202', r_ui=1.0, est=3.910714011255167, details={'actual_k': 30, 'was_impossible': False}),
#  Prediction(uid='4167', iid='2664', r_ui=3.0, est=4.049756806575218, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3111', iid='1265', r_ui=5.0, est=3.3067119168739882, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3885', iid='260', r_ui=5.0, est=4.4265175191536, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1916', iid='589', r_ui=3.0, est=3.8815886991821955, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='960', iid='1213', r_ui=5.0, est=4.316840149177222, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2737', iid='1244', r_ui=2.0, est=3.9261204517228094, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4577', iid='902', r_ui=4.0, est=3.4594418876778175, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4617', iid='1589', r_ui=3.0, est=3.133440478152096, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4977', iid='3704', r_ui=2.0, est=2.7612607829131823, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4092', iid='2371', r_ui=3.0, est=4.214396509518161, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='508', iid='2021', r_ui=3.0, est=3.4335820885931954, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5948', iid='2692', r_ui=5.0, est=4.702259799437385, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='216', iid='265', r_ui=4.0, est=3.347935222528961, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3965', iid='2881', r_ui=4.0, est=3.7776808167137537, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='346', iid='2941', r_ui=4.0, est=4.221512088892533, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='735', iid='2719', r_ui=3.0, est=2.8423303612922877, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5011', iid='2745', r_ui=5.0, est=3.878568707022331, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3751', iid='779', r_ui=3.0, est=2.9658461274664334, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5600', iid='2193', r_ui=4.0, est=4.102977765119055, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='6004', iid='2174', r_ui=2.0, est=3.48812845425286, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='588', iid='949', r_ui=3.0, est=4.19642375249259, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3056', iid='442', r_ui=3.0, est=3.418973581802427, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4085', iid='3436', r_ui=3.0, est=3.3700882986985095, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='196', iid='908', r_ui=4.0, est=4.144902738858992, details={'actual_k': 20, 'was_impossible': False}),
#  Prediction(uid='5614', iid='32', r_ui=5.0, est=3.7296910874669553, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2634', iid='62', r_ui=4.0, est=3.684148979683518, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3900', iid='1541', r_ui=3.0, est=2.9872674194053763, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4292', iid='95', r_ui=2.0, est=2.8421145028999137, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4918', iid='1391', r_ui=2.0, est=3.2064943918347426, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5501', iid='3527', r_ui=4.0, est=3.238428901973295, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5539', iid='2336', r_ui=4.0, est=4.030978384804521, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5852', iid='1994', r_ui=3.0, est=3.5196066329214295, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5888', iid='1201', r_ui=3.0, est=4.259987666544974, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3793', iid='1021', r_ui=1.0, est=2.008637029806218, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5834', iid='2300', r_ui=4.0, est=3.673074833171314, details={'actual_k': 19, 'was_impossible': False}),
#  Prediction(uid='4801', iid='1601', r_ui=5.0, est=4.735434574440097, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5205', iid='2550', r_ui=4.0, est=3.220285591401818, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3333', iid='2571', r_ui=5.0, est=4.054116128385881, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3927', iid='1271', r_ui=5.0, est=4.104838335087284, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3261', iid='2890', r_ui=3.0, est=3.83631665186934, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1449', iid='3704', r_ui=3.0, est=2.3019637703084377, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4600', iid='1876', r_ui=4.0, est=3.3601823658492966, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3108', iid='910', r_ui=5.0, est=4.182393842377301, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1137', iid='923', r_ui=5.0, est=4.426598725013958, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4448', iid='2076', r_ui=5.0, est=4.465894444205276, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3062', iid='3173', r_ui=4.0, est=3.416995812374225, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1141', iid='2059', r_ui=4.0, est=3.2529542438606684, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1421', iid='3159', r_ui=4.0, est=3.6588563554154163, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4086', iid='1584', r_ui=5.0, est=4.630429224587664, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1750', iid='356', r_ui=3.0, est=3.1874944626998083, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1425', iid='1690', r_ui=2.0, est=3.1791403258780777, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5253', iid='596', r_ui=5.0, est=3.875041397852331, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5153', iid='1083', r_ui=3.0, est=3.220849128632212, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2857', iid='511', r_ui=3.0, est=3.121073678748627, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4122', iid='377', r_ui=3.0, est=3.4952710919813814, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1159', iid='3698', r_ui=3.0, est=2.3341834526591554, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='92', iid='2500', r_ui=1.0, est=1.8808065174459259, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4804', iid='3761', r_ui=3.0, est=2.4597618134569137, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='1671', iid='1097', r_ui=3.0, est=3.7944974247126186, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2464', iid='1172', r_ui=4.0, est=3.898401337105314, details={'actual_k': 26, 'was_impossible': False}),
#  Prediction(uid='4088', iid='322', r_ui=5.0, est=3.2179817604544434, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1938', iid='3807', r_ui=3.0, est=3.1458825752626804, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='724', iid='3267', r_ui=3.0, est=3.7450905898902676, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1920', iid='3684', r_ui=5.0, est=3.207848744359188, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1503', iid='1073', r_ui=2.0, est=3.654963183676161, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3123', iid='3638', r_ui=5.0, est=3.400371976383112, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1203', iid='3175', r_ui=4.0, est=3.8329506213984033, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3050', iid='3148', r_ui=5.0, est=3.7287815672577205, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5733', iid='2393', r_ui=3.0, est=3.6976195050506426, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1794', iid='2617', r_ui=1.0, est=2.1544523117550534, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1447', iid='924', r_ui=4.0, est=4.004233929722299, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4408', iid='3363', r_ui=4.0, est=4.0186472329116905, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1303', iid='70', r_ui=2.0, est=2.979209742051464, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4074', iid='3260', r_ui=1.0, est=4.5013504372656055, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='2627', iid='3730', r_ui=4.0, est=3.873495667920685, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4823', iid='529', r_ui=2.0, est=3.8481511158383075, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='679', iid='1228', r_ui=5.0, est=3.9292417162929185, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3675', iid='1806', r_ui=3.0, est=3.007437981209181, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2211', iid='593', r_ui=3.0, est=4.17461452850305, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1317', iid='1271', r_ui=4.0, est=3.9700008836781855, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='552', iid='3153', r_ui=2.0, est=3.9464977703165784, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1671', iid='2144', r_ui=5.0, est=3.823105873339049, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2116', iid='1954', r_ui=4.0, est=3.7896995033898815, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4292', iid='208', r_ui=3.0, est=2.6634835657824056, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5874', iid='3703', r_ui=4.0, est=3.820159412756654, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='752', iid='3761', r_ui=1.0, est=2.5909090909090913, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3618', iid='507', r_ui=3.0, est=2.9671605519085027, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2786', iid='111', r_ui=4.0, est=4.519941211159378, details={'actual_k': 40, 'was_impossible': False}),
#  ...]

# %%
accuracy.rmse(preds)
# Out:
# RMSE: 0.9220
# 0.9219529099076172

# %% [markdown]
# test 데이터 중 예측값과 실제값의 차이가 작은 상위 10개의 best prediction을 보다 상세하게 살펴보면 다음과 같다.

# %%
preds_df = pd.DataFrame(preds)
preds_df.head()
# Out:
#     uid   iid  r_ui       est                                    details
# 0  3718  1234   3.0  3.762351  {'actual_k': 40, 'was_impossible': False}
# 1  4048  1937   5.0  4.077291  {'actual_k': 40, 'was_impossible': False}
# 2  5074  1458   1.0  3.083295  {'actual_k': 40, 'was_impossible': False}
# 3  5502   608   4.0  3.965104  {'actual_k': 40, 'was_impossible': False}
# 4  1903   596   4.0  3.973691  {'actual_k': 40, 'was_impossible': False}

# %% [markdown]
# preds_df 데이터프레임에 예측값과 실제값의 차이를 나타내는 err 열을 추가한다.

# %%
preds_df['err'] = abs(preds_df.est - preds_df.r_ui)
preds_df.head()
# Out:
#     uid   iid  r_ui       est                                    details  \
# 0  3718  1234   3.0  3.762351  {'actual_k': 40, 'was_impossible': False}
# 1  4048  1937   5.0  4.077291  {'actual_k': 40, 'was_impossible': False}
# 2  5074  1458   1.0  3.083295  {'actual_k': 40, 'was_impossible': False}
# 3  5502   608   4.0  3.965104  {'actual_k': 40, 'was_impossible': False}
# 4  1903   596   4.0  3.973691  {'actual_k': 40, 'was_impossible': False}
#
#         err
# 0  0.762351
# 1  0.922709
# 2  2.083295
# 3  0.034896
# 4  0.026309

# %% [markdown]
# err를 기준으로 실제값의 차이가 작은 상위 10개의 best prediction을 살펴본다.

# %%
best_preds = preds_df.sort_values(by='err')[:10]
best_preds
# Out:
#          uid   iid  r_ui  est                                    details  err
# 99126   4169  2350   3.0  3.0  {'actual_k': 40, 'was_impossible': False}  0.0
# 3876    3598   858   1.0  1.0  {'actual_k': 40, 'was_impossible': False}  0.0
# 107392  3598  1617   1.0  1.0  {'actual_k': 40, 'was_impossible': False}  0.0
# 179132  3324  1148   5.0  5.0  {'actual_k': 13, 'was_impossible': False}  0.0
# 34338   3610  1237   1.0  1.0  {'actual_k': 40, 'was_impossible': False}  0.0
# 140417  4016   200   3.0  3.0  {'actual_k': 40, 'was_impossible': False}  0.0
# 289653  3902  3793   5.0  5.0  {'actual_k': 40, 'was_impossible': False}  0.0
# 297775  3902  1304   5.0  5.0  {'actual_k': 40, 'was_impossible': False}  0.0
# 224289  2744   714   1.0  1.0  {'actual_k': 40, 'was_impossible': False}  0.0
# 145176  4277   882   4.0  4.0  {'actual_k': 40, 'was_impossible': False}  0.0

# %% [markdown]
# best prediction 중 10번째 user가 실제로 봤던 영화와 추천받은 영화를 비교하면 아래와 같다.<br>
# 먼저 10번째 user가 실제로 봤던 영화의 제목과 장르를 살펴본다.

# %%
user_MovieID = ratings_df[ratings_df['UserID'] == list(best_preds.uid)[9]]
user_MovieID = user_MovieID['MovieID']
user_MovieID = list(user_MovieID)

# %%
user_Movie = movies_df[movies_df['MovieID'].isin(user_MovieID)]
user_Movie
# Out:
#      MovieID                       Title                        Genres
# 0          1            Toy Story (1995)   Animation|Children's|Comedy
# 1          2              Jumanji (1995)  Adventure|Children's|Fantasy
# 5          6                 Heat (1995)         Action|Crime|Thriller
# 7          8         Tom and Huck (1995)          Adventure|Children's
# 9         10            GoldenEye (1995)     Action|Adventure|Thriller
# ...      ...                         ...                           ...
# 3877    3947           Get Carter (1971)                      Thriller
# 3878    3948     Meet the Parents (2000)                        Comedy
# 3879    3949  Requiem for a Dream (2000)                         Drama
# 3880    3950            Tigerland (2000)                         Drama
# 3882    3952       Contender, The (2000)                Drama|Thriller
#
# [1743 rows x 3 columns]

# %% [markdown]
# 10번째 user가 실제로 즐겨봤던 상위 5개의 영화의 장르를 살펴본다.

# %%
user_Genre = {}
for genre in set(user_Movie['Genres']):
    user_Genre[genre] = list(user_Movie['Genres']).count(genre)

# %%
user_Genre = sorted(user_Genre.items(), key=lambda x:x[1], reverse=True)
user_Genre[:5]
# Out:
# [('Drama', 315),
#  ('Comedy', 133),
#  ('Thriller', 68),
#  ('Comedy|Drama', 68),
#  ('Drama|Thriller', 47)]

# %% [markdown]
# 10번째 user가 추천받은 영화의 제목과 장르를 확인하고 실제 데이터와 비교해본다.<br>
# 10번째 user가 추천받은 영화의 장르와 실제로 해당 user가 즐겨보는 영화의 장르가 유사한 것으로 보아 추천이 잘 이루어졌다고 볼 수 있다.

# %%
recommended_Movie = movies_df[movies_df['MovieID'] == list(best_preds.iid)[9]]
recommended_Movie
# Out:
#     MovieID                       Title          Genres
# 871     882  Trigger Effect, The (1996)  Drama|Thriller

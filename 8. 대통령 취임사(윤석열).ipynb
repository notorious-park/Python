# %% [markdown]
# ### 워드클라우드 : 윤석열대통령 2022년 취임사
# - 청와대 : https://www.president.go.kr/ko/greeting_new.php
# - 과제1. 윤석열대통령 연설문을 크롤링
# - 과제2. 의미없는 글자는 필터링 후 워드클라우드 생성

# %%
# from images import bigpycraft_bda as bpc
from IPython.display import Image

# %%
# !pip install pytagcloud

# %%
# !pip install pygame

# %%
# !pip install simplejson

# %%
from konlpy.tag import Hannanum
from lxml import html
from collections import Counter
from urllib.request import urlopen

import sys
import random
import webbrowser
import pytagcloud

# %%
rndno = lambda: random.randint(0, 255)
color = lambda: (rndno(), rndno(), rndno())

# %%
color()
# Out:
# (208, 179, 216)

# %%
def get_tags(text, ntags=100, multiplier=10):
    hannanum = Hannanum()
    nouns = hannanum.nouns(text)
    count = Counter(nouns)
    return [
        {'color' : color(),
         'tag' : n,
         'size' : c*multiplier,
        }
        for n, c in count.most_common(ntags)
    ]

# %%
def draw_cloud(tags, filename, fontname='Korean', size=(500, 400)):
    pytagcloud.create_tag_image(tags, filename, fontname=fontname, size=size)
    # webbrowser.open(filename)

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
url = 'https://www.president.go.kr/ko/greeting_new.php'
html = urlopen(url)
soup = BeautifulSoup(html, 'lxml')
soup.title
# Out:
# <title>제20대 대통령실 &gt; 국민의 대통령 &gt; 윤석열 대통령</title>

# %%
speech = soup.find('div', 'gre')
speech
# Out:
# <div class="gre">
# <div class="inner">
# <div class="pic" data-aos="fade-up" data-aos-delay="0"></div>
# <div class="wrap" data-aos="fade-up" data-aos-delay="0">
# <div class="title">
# 						존경하고 사랑하는 국민 여러분,<br/>
# 						750만 재외동포 여러분<br/>
# 						그리고 자유를 사랑하는 세계 시민 여러분
# 					</div>
# <div class="txt">
# 						저는 이 나라를 자유민주주의와 시장경제 체제를 기반으로<br/>
# 						국민이 진정한 주인인 나라로 재건하고,<br/>
# 						국제사회에서 책임과 역할을 다하는 나라로 만들어야 하는 시대적 소명을 갖고<br class="__p"/>
# 						오늘 이 자리에 섰습니다.<br/>
# <br/>
# 						역사적인 자리에 함께 해주신 국민 여러분께 감사드립니다.<br/>
# <br/>
# 						문재인, 박근혜 전 대통령,<br/>
# 						그리고 할리마 야콥 싱가포르 대통령,<br/>
# 						포스탱 아르샹쥬 투아데라 중앙아프리카공화국 대통령,<br/>
# 						왕치산 중국 국가부주석,<br/>
# 						메가와티 수카르노푸트리 인도네시아 전 대통령,<br/>
# 						더글러스 엠호프 해리스 미국 부통령 부군,<br/>
# 						조지 퓨리 캐나다 상원의장,<br/>
# 						하야시 요시마사 일본 외무상을 비롯한 <br class="__m2"/>세계 각국의 경축 사절과<br class="__p"/>
# 						내외 귀빈 여러분께도 <br class="__m2"/>깊이 감사드립니다.<br/>
# <br/>
# 						이 자리를 빌려 지난 2년간 <br class="__m2"/>코로나 펜데믹을 극복하는 과정에서<br/>
# 						큰 고통을 감내해주신 국민 여러분께 경의를 표합니다.<br/>
# 						그리고 헌신해주신 의료진 여러분께도 감사드립니다.<br/>
# <br/>
# 						존경하는 국민 여러분<br/>
# 						세계 시민 여러분<br/>
# <br/>
# 						지금 전 세계는 팬데믹 위기, 교역 질서의 변화와 <br class="__m2"/>공급망의 재편,<br class="__p"/>
# 						기후 변화, 식량과 에너지 위기, <br class="__m2"/>분쟁의 평화적 해결의 후퇴 등<br class="__p"/>
# 						어느 한 나라가 독자적으로, 또는 몇몇 나라만 참여해서 해결하기 어려운<br/>
# 						난제들에 직면해 있습니다.<br/>
# <br/>
# 						다양한 위기가 복합적으로 인류 사회에 어두운 그림자를 드리우고 있는 것입니다.<br/>
# <br/>
# 						또한 우리나라를 비롯한 많은 나라들이 <br class="__m2"/>국내적으로 초저성장과 대규모 실업, <br class="__m2"/>양극화의 심화와 다양한 사회적 갈등으로 인해<br/>
# 						공동체의 결속력이 흔들리고 와해되고 있습니다.<br/>
# <br/>
# 						한편, 이러한 문제들을 해결해야 하는 정치는 <br/>이른바 민주주의의 위기로 인해 제 기능을 하지 못하고 있습니다.<br/>
# <br/>
# 						가장 큰 원인으로 지목되는 것이 바로 반지성주의입니다.<br/>
# <br/>
# 						견해가 다른 사람들이 서로의 입장을 조정하고 <br class="__m2"/>타협하기 위해서는 <br class="__p"/>
# 						과학과 진실이 전제되어야 합니다. <br/>
# 						그것이 민주주의를 지탱하는 합리주의와 지성주의입니다.<br/>
# <br/>
# 						국가 간, 국가 내부의 <br class="__m2"/>지나친 집단적 갈등에 의해 진실이 왜곡되고,<br/>
# 						각자가 보고 듣고 싶은 사실만을 선택하거나<br/>
# 						다수의 힘으로 상대의 의견을 억압하는 반지성주의가 민주주의를 위기에 빠뜨리고<br/>
# 						민주주의에 대한 믿음을 해치고 있습니다.<br/>
# 						이러한 상황이 우리가 처해있는 문제의 해결을 <br class="__m2"/>더 어렵게 만들고 있습니다.<br/>
# <br/>
# 						그러나 우리는 할 수 있습니다.<br/>
# 						역사를 돌이켜 보면 우리 국민은 많은 위기에 처했지만<br/>
# 						그럴 때마다 국민 모두 힘을 합쳐 지혜롭게, <br class="__m2"/>또 용기있게 극복해 왔습니다.<br/>
# <br/>
# 						저는 이 순간 이러한 위기를 극복하는 책임을<br/>
# 						부여받게 된 것을 감사한 마음으로 받아들이고,<br/>
# 						우리 위대한 국민과 함께 당당하게 헤쳐 나갈 수 있다고 확신합니다.<br/>
# <br/>
# 						또 세계 시민과 힘을 합쳐 국내외적인 위기와 난제들을 <br/>해결해 나갈 수 있다고 믿습니다.<br/>
# <br/>
# 						존경하는 국민 여러분<br/>
# 						세계 시민 여러분<br/>
# <br/>
# 						저는 이 어려움을 해결해 나가기 위해서<br/>우리가 보편적 가치를 공유하는 것이 매우 중요하다고 생각합니다.<br/>
# <br/>
# 						그것은 바로 ‘자유’입니다.<br/>
# 						우리는 자유의 가치를 제대로, <br class="__m2"/>그리고 정확하게 인식해야 합니다.<br/>
# 						자유의 가치를 재발견해야 합니다.<br/>
# <br/>
# 						인류 역사를 돌이켜보면 자유로운 정치적 권리, <br class="__m2"/>자유로운 시장이 숨 쉬고 있던 곳은 <br class="__m2"/>언제나 번영과 풍요가 꽃 피었습니다.<br/>
# <br/>
# 						번영과 풍요, 경제적 성장은 바로 자유의 확대입니다.<br/>
# <br/>
# 						자유는 보편적 가치입니다.<br/>
# 						우리 사회 모든 구성원이 자유 시민이 되어야 <br class="__m2"/>하는 것입니다.<br/>
# 						어떤 개인의 자유가 침해되는 것이 방치된다면<br/>
# 						우리 공동체 구성원 모두의 자유마저 위협받게 됩니다.<br/>
# <br/>
# 						자유는 결코 승자독식이 아닙니다.<br/>
# 						자유 시민이 되기 위해서는 일정한 수준의 경제적 기초,<br/>
# 						그리고 공정한 교육과 문화의 접근 기회가 <br class="__m2"/>보장되어야 합니다.<br/>
# 						이런 것 없이 자유 시민이라고 할 수 없습니다.<br/>
# <br/>
# 						어떤 사람의 자유가 유린되거나 <br/>
# 						자유 시민이 되는데 필요한 조건을 충족하지 못한다면 <br/>
# 						모든 자유 시민은 연대해서 도와야 합니다.<br/>
# <br/>
# 						그리고 개별 국가뿐 아니라 국제적으로도<br/>
# 						기아와 빈곤, 공권력과 군사력에 의한 불법 행위로 <br class="__m2"/>개인의 자유가 침해되고<br/>
# 						자유 시민으로서의 존엄한 삶이 유지되지 않는다면<br/>
# 						모든 세계 시민이 자유 시민으로서 연대하여 도와야 <br class="__m2"/>하는 것입니다.<br/>
# <br/>
# 						모두가 자유 시민이 되기 위해서는 <br class="__m2"/>공정한 규칙을 지켜야 하고,<br/>
# 						연대와 박애의 정신을 가져야 합니다.<br/>
# <br/>
# 						존경하는 국민 여러분<br/>
# <br/>
# 						국내 문제로 눈을 돌려 제가 중요하게 생각하는 <br class="__m2"/>방향에 대해 말씀드리겠습니다.<br/>
# <br/>
# 						우리나라는 지나친 양극화와 사회 갈등이 <br class="__m2"/>자유와 민주주의를 위협할 뿐 아니라<br/>
# 						사회 발전의 발목을 잡고 있습니다.<br/>
# <br/>
# 						저는 이 문제를 도약과 빠른 성장을 이룩하지 않고는 해결하기 어렵다고 생각합니다.<br/>
# <br/>
# 						빠른 성장 과정에서 <br class="__m2"/>많은 국민이 새로운 기회를 찾을 수 있고,<br/>
# 						사회 이동성을 제고함으로써 양극화와 갈등의 근원을 <br class="__m2"/>제거할 수 있습니다.<br/>
# <br/>
# 						도약과 빠른 성장은 오로지 과학과 기술, <br class="__m2"/>그리고 혁신에 의해서만<br class="__p"/>
# 						이뤄낼 수 있는 것입니다.<br/>
# <br/>
# 						과학과 기술, 그리고 혁신은 <br class="__m2"/>우리의 자유민주주의를 지키고<br class="__ㅔ"/>
# 						우리의 자유를 확대하며 <br class="__m2"/>우리의 존엄한 삶을 지속 가능하게 할 것입니다.<br/>
# <br/>
# 						과학과 기술, 그리고 혁신은 <br class="__m2"/>우리나라 혼자만의 노력으로는 달성하기 어렵습니다.<br/>
# <br/>
# 						자유와 창의를 존중함으로써 <br class="__m2"/>과학 기술의 진보와 혁신을 이뤄낸 많은 나라들과 <br class="__m2"/>협력하고 연대해야만 합니다.<br/>
# <br/>
# 						존경하는 국민 여러분<br/>
# 						세계 시민 여러분<br/>
# <br/>
# 						자유민주주의는 평화를 만들어내고, <br class="__m2"/>평화는 자유를 지켜줍니다. <br/>
# 						그리고 평화는 자유와 인권의 가치를 존중하는 <br/>
# 						국제사회와의 연대에 의해 보장이 됩니다.<br/>
# <br/>
# 						일시적으로 전쟁을 회피하는 취약한 평화가 아니라 <br/>
# 						자유와 번영을 꽃피우는 <br class="__m2"/>지속 가능한 평화를 추구해야 합니다.<br/>
# <br/>
# 						전 세계 어떤 곳도 자유와 평화에 대한 위협에서 <br class="__m2"/>자유롭지 못합니다. <br/>
# 						지금 한반도와 동북아의 평화도 마찬가지입니다.<br/>
# <br/>
# 						저는 한반도뿐 아니라 아시아와 세계의 평화를 위협하는 <br/>
# 						북한의 핵 개발에 대해서도 <br class="__m2"/>그 평화적 해결을 위해 대화의 문을 열어놓겠습니다.<br/>
# <br/>
# 						그리고 북한이 핵 개발을 중단하고 <br class="__m2"/>실질적인 비핵화로 전환한다면 <br/>
# 						국제사회와 협력하여 <br class="__m2"/>북한 경제와 북한 주민의 삶의 질을 <br/>
# 						획기적으로 개선할 수 있는 담대한 계획을 준비하겠습니다.<br/>
# <br/>
# 						북한의 비핵화는 <br class="__m2"/>한반도에 지속 가능한 평화를 가져올 뿐 아니라 <br/>
# 						아시아와 전 세계의 평화와 번영에도 <br class="__m2"/>크게 기여할 것입니다.<br/>
# <br/>
# 						사랑하고 존경하는 국민 여러분<br/>
# <br/>
# 						지금 우리는 세계 10위권의 경제 대국 그룹에 <br class="__m2"/>들어가 있습니다.<br/>
# 						그러므로 우리는 자유와 인권의 가치에 기반한 <br/>
# 						보편적 국제 규범을 적극 지지하고 수호하는데 <br/>
# 						글로벌 리더 국가로서의 자세를 가져야 합니다.<br/>
# <br/>
# 						우리나라뿐 아니라 <br class="__m2"/>세계 시민 모두의 자유와 인권을 지키고 확대하는데 <br/>
# 						더욱 주도적인 역할을 해야 합니다. <br/>
# 						국제사회도 대한민국에 더욱 큰 역할을 <br class="__m2"/>기대하고 있음이 분명합니다.<br/>
# <br/>
# 						지금 우리나라는 국내 문제와 국제 문제를 <br class="__m2"/>분리할 수 없습니다.<br/>
# 						국제사회가 우리에게 기대하는 역할을 <br class="__m2"/>주도적으로 수행할 때 <br/>
# 						국내 문제도 올바른 해결 방향을 찾을 수 있는 것입니다.<br/>
# <br/>
# 						저는 자유, 인권, 공정, 연대의 가치를 기반으로 <br/>
# 						국민이 진정한 주인인 나라,<br/>
# 						국제사회에서 책임을 다하고 존경받는 나라를<br/>
# 						위대한 국민 여러분과 함께<br/>
# 						반드시 만들어 나가겠습니다.<br/>
# <br/>
# 						감사합니다.
# 					</div>
# <div class="sign">
# <span>대통령</span>
# <strong>윤석열</strong>
# </div>
# </div>
# </div>
# </div>

# %%
speech_txt = speech.get_text()
speech_txt
# Out:
# '\n\n\n\n\r\n\t\t\t\t\t\t존경하고 사랑하는 국민 여러분,\r\n\t\t\t\t\t\t750만 재외동포 여러분\r\n\t\t\t\t\t\t그리고 자유를 사랑하는 세계 시민 여러분\r\n\t\t\t\t\t\n\r\n\t\t\t\t\t\t저는 이 나라를 자유민주주의와 시장경제 체제를 기반으로\r\n\t\t\t\t\t\t국민이 진정한 주인인 나라로 재건하고,\r\n\t\t\t\t\t\t국제사회에서 책임과 역할을 다하는 나라로 만들어야 하는 시대적 소명을 갖고\r\n\t\t\t\t\t\t오늘 이 자리에 섰습니다.\n\r\n\t\t\t\t\t\t역사적인 자리에 함께 해주신 국민 여러분께 감사드립니다.\n\r\n\t\t\t\t\t\t문재인, 박근혜 전 대통령,\r\n\t\t\t\t\t\t그리고 할리마 야콥 싱가포르 대통령,\r\n\t\t\t\t\t\t포스탱 아르샹쥬 투아데라 중앙아프리카공화국 대통령,\r\n\t\t\t\t\t\t왕치산 중국 국가부주석,\r\n\t\t\t\t\t\t메가와티 수카르노푸트리 인도네시아 전 대통령,\r\n\t\t\t\t\t\t더글러스 엠호프 해리스 미국 부통령 부군,\r\n\t\t\t\t\t\t조지 퓨리 캐나다 상원의장,\r\n\t\t\t\t\t\t하야시 요시마사 일본 외무상을 비롯한 세계 각국의 경축 사절과\r\n\t\t\t\t\t\t내외 귀빈 여러분께도 깊이 감사드립니다.\n\r\n\t\t\t\t\t\t이 자리를 빌려 지난 2년간 코로나 펜데믹을 극복하는 과정에서\r\n\t\t\t\t\t\t큰 고통을 감내해주신 국민 여러분께 경의를 표합니다.\r\n\t\t\t\t\t\t그리고 헌신해주신 의료진 여러분께도 감사드립니다.\n\r\n\t\t\t\t\t\t존경하는 국민 여러분\r\n\t\t\t\t\t\t세계 시민 여러분\n\r\n\t\t\t\t\t\t지금 전 세계는 팬데믹 위기, 교역 질서의 변화와 공급망의 재편,\r\n\t\t\t\t\t\t기후 변화, 식량과 에너지 위기, 분쟁의 평화적 해결의 후퇴 등\r\n\t\t\t\t\t\t어느 한 나라가 독자적으로, 또는 몇몇 나라만 참여해서 해결하기 어려운\r\n\t\t\t\t\t\t난제들에 직면해 있습니다.\n\r\n\t\t\t\t\t\t다양한 위기가 복합적으로 인류 사회에 어두운 그림자를 드리우고 있는 것입니다.\n\r\n\t\t\t\t\t\t또한 우리나라를 비롯한 많은 나라들이 국내적으로 초저성장과 대규모 실업, 양극화의 심화와 다양한 사회적 갈등으로 인해\r\n\t\t\t\t\t\t공동체의 결속력이 흔들리고 와해되고 있습니다.\n\r\n\t\t\t\t\t\t한편, 이러한 문제들을 해결해야 하는 정치는 이른바 민주주의의 위기로 인해 제 기능을 하지 못하고 있습니다.\n\r\n\t\t\t\t\t\t가장 큰 원인으로 지목되는 것이 바로 반지성주의입니다.\n\r\n\t\t\t\t\t\t견해가 다른 사람들이 서로의 입장을 조정하고 타협하기 위해서는 \r\n\t\t\t\t\t\t과학과 진실이 전제되어야 합니다. \r\n\t\t\t\t\t\t그것이 민주주의를 지탱하는 합리주의와 지성주의입니다.\n\r\n\t\t\t\t\t\t국가 간, 국가 내부의 지나친 집단적 갈등에 의해 진실이 왜곡되고,\r\n\t\t\t\t\t\t각자가 보고 듣고 싶은 사실만을 선택하거나\r\n\t\t\t\t\t\t다수의 힘으로 상대의 의견을 억압하는 반지성주의가 민주주의를 위기에 빠뜨리고\r\n\t\t\t\t\t\t민주주의에 대한 믿음을 해치고 있습니다.\r\n\t\t\t\t\t\t이러한 상황이 우리가 처해있는 문제의 해결을 더 어렵게 만들고 있습니다.\n\r\n\t\t\t\t\t\t그러나 우리는 할 수 있습니다.\r\n\t\t\t\t\t\t역사를 돌이켜 보면 우리 국민은 많은 위기에 처했지만\r\n\t\t\t\t\t\t그럴 때마다 국민 모두 힘을 합쳐 지혜롭게, 또 용기있게 극복해 왔습니다.\n\r\n\t\t\t\t\t\t저는 이 순간 이러한 위기를 극복하는 책임을\r\n\t\t\t\t\t\t부여받게 된 것을 감사한 마음으로 받아들이고,\r\n\t\t\t\t\t\t우리 위대한 국민과 함께 당당하게 헤쳐 나갈 수 있다고 확신합니다.\n\r\n\t\t\t\t\t\t또 세계 시민과 힘을 합쳐 국내외적인 위기와 난제들을 해결해 나갈 수 있다고 믿습니다.\n\r\n\t\t\t\t\t\t존경하는 국민 여러분\r\n\t\t\t\t\t\t세계 시민 여러분\n\r\n\t\t\t\t\t\t저는 이 어려움을 해결해 나가기 위해서우리가 보편적 가치를 공유하는 것이 매우 중요하다고 생각합니다.\n\r\n\t\t\t\t\t\t그것은 바로 ‘자유’입니다.\r\n\t\t\t\t\t\t우리는 자유의 가치를 제대로, 그리고 정확하게 인식해야 합니다.\r\n\t\t\t\t\t\t자유의 가치를 재발견해야 합니다.\n\r\n\t\t\t\t\t\t인류 역사를 돌이켜보면 자유로운 정치적 권리, 자유로운 시장이 숨 쉬고 있던 곳은 언제나 번영과 풍요가 꽃 피었습니다.\n\r\n\t\t\t\t\t\t번영과 풍요, 경제적 성장은 바로 자유의 확대입니다.\n\r\n\t\t\t\t\t\t자유는 보편적 가치입니다.\r\n\t\t\t\t\t\t우리 사회 모든 구성원이 자유 시민이 되어야 하는 것입니다.\r\n\t\t\t\t\t\t어떤 개인의 자유가 침해되는 것이 방치된다면\r\n\t\t\t\t\t\t우리 공동체 구성원 모두의 자유마저 위협받게 됩니다.\n\r\n\t\t\t\t\t\t자유는 결코 승자독식이 아닙니다.\r\n\t\t\t\t\t\t자유 시민이 되기 위해서는 일정한 수준의 경제적 기초,\r\n\t\t\t\t\t\t그리고 공정한 교육과 문화의 접근 기회가 보장되어야 합니다.\r\n\t\t\t\t\t\t이런 것 없이 자유 시민이라고 할 수 없습니다.\n\r\n\t\t\t\t\t\t어떤 사람의 자유가 유린되거나 \r\n\t\t\t\t\t\t자유 시민이 되는데 필요한 조건을 충족하지 못한다면 \r\n\t\t\t\t\t\t모든 자유 시민은 연대해서 도와야 합니다.\n\r\n\t\t\t\t\t\t그리고 개별 국가뿐 아니라 국제적으로도\r\n\t\t\t\t\t\t기아와 빈곤, 공권력과 군사력에 의한 불법 행위로 개인의 자유가 침해되고\r\n\t\t\t\t\t\t자유 시민으로서의 존엄한 삶이 유지되지 않는다면\r\n\t\t\t\t\t\t모든 세계 시민이 자유 시민으로서 연대하여 도와야 하는 것입니다.\n\r\n\t\t\t\t\t\t모두가 자유 시민이 되기 위해서는 공정한 규칙을 지켜야 하고,\r\n\t\t\t\t\t\t연대와 박애의 정신을 가져야 합니다.\n\r\n\t\t\t\t\t\t존경하는 국민 여러분\n\r\n\t\t\t\t\t\t국내 문제로 눈을 돌려 제가 중요하게 생각하는 방향에 대해 말씀드리겠습니다.\n\r\n\t\t\t\t\t\t우리나라는 지나친 양극화와 사회 갈등이 자유와 민주주의를 위협할 뿐 아니라\r\n\t\t\t\t\t\t사회 발전의 발목을 잡고 있습니다.\n\r\n\t\t\t\t\t\t저는 이 문제를 도약과 빠른 성장을 이룩하지 않고는 해결하기 어렵다고 생각합니다.\n\r\n\t\t\t\t\t\t빠른 성장 과정에서 많은 국민이 새로운 기회를 찾을 수 있고,\r\n\t\t\t\t\t\t사회 이동성을 제고함으로써 양극화와 갈등의 근원을 제거할 수 있습니다.\n\r\n\t\t\t\t\t\t도약과 빠른 성장은 오로지 과학과 기술, 그리고 혁신에 의해서만\r\n\t\t\t\t\t\t이뤄낼 수 있는 것입니다.\n\r\n\t\t\t\t\t\t과학과 기술, 그리고 혁신은 우리의 자유민주주의를 지키고\r\n\t\t\t\t\t\t우리의 자유를 확대하며 우리의 존엄한 삶을 지속 가능하게 할 것입니다.\n\r\n\t\t\t\t\t\t과학과 기술, 그리고 혁신은 우리나라 혼자만의 노력으로는 달성하기 어렵습니다.\n\r\n\t\t\t\t\t\t자유와 창의를 존중함으로써 과학 기술의 진보와 혁신을 이뤄낸 많은 나라들과 협력하고 연대해야만 합니다.\n\r\n\t\t\t\t\t\t존경하는 국민 여러분\r\n\t\t\t\t\t\t세계 시민 여러분\n\r\n\t\t\t\t\t\t자유민주주의는 평화를 만들어내고, 평화는 자유를 지켜줍니다. \r\n\t\t ...

# %%
speech_txt = speech_txt.replace('\n', ' ')
speech_txt = speech_txt.replace('\r', ' ')
speech_txt = speech_txt.replace('\t', ' ')
speech_txt = speech_txt.replace('\xa0', ' ')
speech_txt = speech_txt.replace('것', ' ')
speech_txt = speech_txt.replace('위', ' ')
speech_txt = speech_txt.replace('등', ' ')
speech_txt = speech_txt.replace('곳', ' ')
speech_txt = speech_txt.replace('극', ' ')
speech_txt = speech_txt.replace('전', ' ')
speech_txt = speech_txt.replace('기', ' ')
speech_txt = speech_txt.replace('수', ' ')
speech_txt = speech_txt.strip()
speech_txt
# Out:
# '존경하고 사랑하는 국민 여러분,        750만 재외동포 여러분        그리고 자유를 사랑하는 세계 시민 여러분                저는 이 나라를 자유민주주의와 시장경제 체제를  반으로        국민이 진정한 주인인 나라로 재건하고,        국제사회에서 책임과 역할을 다하는 나라로 만들어야 하는 시대적 소명을 갖고        오늘 이 자리에 섰습니다.         역사적인 자리에 함께 해주신 국민 여러분께 감사드립니다.         문재인, 박근혜   대통령,        그리고 할리마 야콥 싱가포르 대통령,        포스탱 아르샹쥬 투아데라 중앙아프리카공화국 대통령,        왕치산 중국 국가부주석,        메가와티  카르노푸트리 인도네시아   대통령,        더글러스 엠호프 해리스 미국 부통령 부군,        조지 퓨리 캐나다 상원의장,        하야시 요시마사 일본 외무상을 비롯한 세계 각국의 경축 사절과        내외 귀빈 여러분께도 깊이 감사드립니다.         이 자리를 빌려 지난 2년간 코로나 펜데믹을  복하는 과정에서        큰 고통을 감내해주신 국민 여러분께 경의를 표합니다.        그리고 헌신해주신 의료진 여러분께도 감사드립니다.         존경하는 국민 여러분        세계 시민 여러분         지금   세계는 팬데믹   , 교역 질서의 변화와 공급망의 재편,         후 변화, 식량과 에너지   , 분쟁의 평화적 해결의 후퇴          어느 한 나라가 독자적으로, 또는 몇몇 나라만 참여해서 해결하  어려운        난제들에 직면해 있습니다.         다양한   가 복합적으로 인류 사회에 어두운 그림자를 드리우고 있는  입니다.         또한 우리나라를 비롯한 많은 나라들이 국내적으로 초저성장과 대규모 실업, 양 화의 심화와 다양한 사회적 갈 으로 인해        공동체의 결속력이 흔들리고 와해되고 있습니다.         한편, 이러한 문제들을 해결해야 하는 정치는 이른바 민주주의의   로 인해 제  능을 하지 못하고 있습니다.         가장 큰 원인으로 지목되는  이 바로 반지성주의입니다.         견해가 다른 사람들이 서로의 입장을 조정하고 타협하   해서는         과학과 진실이  제되어야 합니다.         그 이 민주주의를 지탱하는 합리주의와 지성주의입니다.         국가 간, 국가 내부의 지나친 집단적 갈 에 의해 진실이 왜곡되고,        각자가 보고 듣고 싶은 사실만을 선택하거나        다 의 힘으로 상대의 의견을 억압하는 반지성주의가 민주주의를   에 빠뜨리고        민주주의에 대한 믿음을 해치고 있습니다.        이러한 상황이 우리가 처해있는 문제의 해결을 더 어렵게 만들고 있습니다.         그러나 우리는 할   있습니다.        역사를 돌이켜 보면 우리 국민은 많은   에 처했지만        그럴 때마다 국민 모두 힘을 합쳐 지혜롭게, 또 용 있게  복해 왔습니다.         저는 이 순간 이러한   를  복하는 책임을        부여받게 된  을 감사한 마음으로 받아들이고,        우리  대한 국민과 함께 당당하게 헤쳐 나갈   있다고 확신합니다.         또 세계 시민과 힘을 합쳐 국내외적인   와 난제들을 해결해 나갈   있다고 믿습니다.         존경하는 국민 여러분        세계 시민 여러분         저는 이 어려움을 해결해 나가   해서우리가 보편적 가치를 공유하는  이 매우 중요하다고 생각합니다.         그 은 바로 ‘자유’입니다.        우리는 자유의 가치를 제대로, 그리고 정확하게 인식해야 합니다.        자유의 가치를 재발견해야 합니다.         인류 역사를 돌이켜보면 자유로운 정치적 권리, 자유로운 시장이 숨 쉬고 있던  은 언제나 번영과 풍요가 꽃 피었습니다.         번영과 풍요, 경제적 성장은 바로 자유의 확대입니다.         자유는 보편적 가치입니다.        우리 사회 모든 구성원이 자유 시민이 되어야 하는  입니다.        어떤 개인의 자유가 침해되는  이 방치된다면        우리 공동체 구성원 모두의 자유마저  협받게 됩니다.         자유는 결코 승자독식이 아닙니다.        자유 시민이 되   해서는 일정한  준의 경제적  초,        그리고 공정한 교육과 문화의 접근  회가 보장되어야 합니다.        이런   없이 자유 시민이라고 할   없습니다.         어떤 사람의 자유가 유린되거나         자유 시민이 되는데 필요한 조건을 충족하지 못한다면         모든 자유 시민은 연대해서 도와야 합니다.         그리고 개별 국가뿐 아니라 국제적으로도         아와 빈곤, 공권력과 군사력에 의한 불법 행 로 개인의 자유가 침해되고        자유 시민으로서의 존엄한 삶이 유지되지 않는다면        모든 세계 시민이 자유 시민으로서 연대하여 도와야 하는  입니다.         모두가 자유 시민이 되   해서는 공정한 규칙을 지켜야 하고,        연대와 박애의 정신을 가져야 합니다.         존경하는 국민 여러분         국내 문제로 눈을 돌려 제가 중요하게 생각하는 방향에 대해 말씀드리겠습니다.         우리나라는 지나친 양 화와 사회 갈 이 자유와 민주주의를  협할 뿐 아니라        사회 발 의 발목을 잡고 있습니다.         저는 이 문제를 도약과 빠른 성장을 이룩하지 않고는 해결하  어렵다고 생각합니다.         빠른 성장 과정에서 많은 국민이 새로운  회를 찾을   있고,        사회 이동성을 제고함으로써 양 화와 갈 의 근원을 제거할   있습니다.         도약과 빠른 성장은 오로지 과학과  술, 그리고 혁신에 의해서만        이뤄낼   있는  입니다.         과학과  술, 그리고 혁신은 우리의 자유민주주의를 지키고        우리의 자유를 확대하며 우리의 존엄한 삶을 지속 가능하게 할  입니다.         과학과  술, 그리고 혁신은 우리나라 혼자만의 노력으로는 달성하  어렵습니다.         자유와 창의를 존중함으로써 과학  술의 진보와 혁신을 이뤄낸 많은 나라들과 협력하고 연대해야만 합니다.         존경하는 국민 여러분        세계 시민 여러분         자유민주주의는 평화를 만들어내고, 평화는 자유를 지켜줍니다.         그리고 평화는 자유와 인권의 가치를 존중하는         국제사회와의 연대에 의해 보장이 됩니다.         일시적으로  쟁을 회피하는 취약한 평화가 아니라         자유와 번영을 꽃피우는 지속 가능한 평화를 추구해야 합니다.           세계 어떤  도 자유와 평화에 대한  협에서 자유롭지 못합니다.         지금 한반도와 동북아의 평화도 마찬가지입니다.         저는 한반도뿐 아니라 아시아와 세계의 평화를  협하는         북한의 핵 개발에 대해서도 그 평화적 해결을  해 대화의 문을 열어놓겠습니다.         그리고 북한이 핵 개발을 중단하고 실질적인 비핵화로  환한다면         국제사회와 협력하여 북한 경제와 북한 주민의 삶의 질을         획 적으로 개선할   있는 담대한 계획을 준비하겠습니다.         북한의 비핵화는 한반도에 지속 가능한 평화를 가져올 뿐 아니라         아시아와   세계의 평화와 번영에도 크게  여할  입니다.         사랑하고 존경하는 국민 여러분         지금 우리는 세계 10 권의 경제 대국 그룹에 들어가 있습니다.        그러므로 우리는 자유와 인권의 가치에  반한         보편적 국제 규범을 적  지지하고  호하는데         글로벌 리더 국가로서의 자세를 가져야 합니다.         우리나라뿐 아니라 세계 시민 모두의 자유와 인권을 지키고 확대하는데         더욱 주도적인 역할을 해야 합니다.      ...

# %%
speech_tags = get_tags(speech_txt)
speech_tags
# Out:
# [{'color': (126, 252, 174), 'tag': '자유', 'size': 290},
#  {'color': (136, 20, 175), 'tag': '여러분', 'size': 160},
#  {'color': (77, 245, 245), 'tag': '국민', 'size': 150},
#  {'color': (236, 7, 237), 'tag': '시민', 'size': 150},
#  {'color': (188, 20, 255), 'tag': '세계', 'size': 130},
#  {'color': (100, 20, 203), 'tag': '우리', 'size': 130},
#  {'color': (222, 116, 108), 'tag': '평화', 'size': 100},
#  {'color': (222, 144, 181), 'tag': '해결', 'size': 90},
#  {'color': (180, 95, 97), 'tag': '저', 'size': 80},
#  {'color': (62, 124, 42), 'tag': '존경', 'size': 70},
#  {'color': (164, 92, 99), 'tag': '가치', 'size': 70},
#  {'color': (171, 127, 84), 'tag': '국제사회', 'size': 60},
#  {'color': (28, 69, 143), 'tag': '문제', 'size': 60},
#  {'color': (130, 105, 83), 'tag': '나라', 'size': 50},
#  {'color': (45, 19, 140), 'tag': '대통령', 'size': 50},
#  {'color': (61, 75, 222), 'tag': '사회', 'size': 50},
#  {'color': (199, 153, 130), 'tag': '우리나라', 'size': 50},
#  {'color': (193, 104, 185), 'tag': '민주주의', 'size': 50},
#  {'color': (211, 244, 208), 'tag': '과학', 'size': 50},
#  {'color': (10, 155, 100), 'tag': '북한', 'size': 50},
#  {'color': (226, 209, 175), 'tag': '역할', 'size': 40},
#  {'color': (221, 117, 24), 'tag': '번영', 'size': 40},
#  {'color': (221, 119, 23), 'tag': '성장', 'size': 40},
#  {'color': (180, 209, 82), 'tag': '연대', 'size': 40},
#  {'color': (75, 144, 3), 'tag': '술', 'size': 40},
#  {'color': (147, 144, 234), 'tag': '혁신', 'size': 40},
#  {'color': (193, 70, 42), 'tag': '인권', 'size': 40},
#  {'color': (137, 42, 182), 'tag': '사랑', 'size': 30},
#  {'color': (249, 94, 164), 'tag': '자유민주주의', 'size': 30},
#  {'color': (81, 22, 164), 'tag': '책', 'size': 30},
#  {'color': (59, 90, 149), 'tag': '자리', 'size': 30},
#  {'color': (81, 59, 252), 'tag': '복', 'size': 30},
#  {'color': (96, 33, 156), 'tag': '양', 'size': 30},
#  {'color': (178, 58, 180), 'tag': '화', 'size': 30},
#  {'color': (100, 123, 238), 'tag': '제', 'size': 30},
#  {'color': (117, 120, 155), 'tag': '의', 'size': 30},
#  {'color': (109, 219, 80), 'tag': '힘', 'size': 30},
#  {'color': (124, 80, 199), 'tag': '보편적', 'size': 30},
#  {'color': (152, 2, 181), 'tag': '생각', 'size': 30},
#  {'color': (33, 236, 234), 'tag': '확대', 'size': 30},
#  {'color': (164, 101, 81), 'tag': '모두', 'size': 30},
#  {'color': (184, 134, 178), 'tag': '삶', 'size': 30},
#  {'color': (163, 104, 159), 'tag': '국내', 'size': 30},
#  {'color': (229, 9, 227), 'tag': '지속', 'size': 30},
#  {'color': (64, 122, 130), 'tag': '가능', 'size': 30},
#  {'color': (208, 42, 240), 'tag': '반', 'size': 20},
#  {'color': (80, 76, 157), 'tag': '진정한', 'size': 20},
#  {'color': (83, 89, 90), 'tag': '주인', 'size': 20},
#  {'color': (112, 231, 200), 'tag': '리', 'size': 20},
#  {'color': (124, 210, 180), 'tag': '부', 'size': 20},
#  {'color': (216, 129, 211), 'tag': '비롯', 'size': 20},
#  {'color': (140, 8, 104), 'tag': '과정', 'size': 20},
#  {'color': (232, 40, 187), 'tag': '질', 'size': 20},
#  {'color': (18, 224, 226), 'tag': '변화', 'size': 20},
#  {'color': (7, 174, 181), 'tag': '평화적', 'size': 20},
#  {'color': (178, 174, 81), 'tag': '난제들', 'size': 20},
#  {'color': (188, 247, 178), 'tag': '인류', 'size': 20},
#  {'color': (62, 50, 68), 'tag': '나라들', 'size': 20},
#  {'color': (227, 193, 84), 'tag': '공동체', 'size': 20},
#  {'color': (49, 97, 14), 'tag': '로', 'size': 20},
#  {'color': (135, 244, 28), 'tag': '반지성주의', 'size': 20},
#  {'color': (96, 26, 164), 'tag': '사람', 'size': 20},
#  {'color': (250, 199, 131), 'tag': '진실', 'size': 20},
#  {'color': (207, 225, 99), 'tag': '국', 'size': 20},
#  {'color': (123, 155, 197), 'tag': '역사', 'size': 20},
#  {'color': (20, 243, 63), 'tag': '때', 'size': 20},
#  {'color': (120, 75, 78), 'tag': '감사', 'size': 20},
#  {'color': (226, 43, 18), 'tag': '나', 'size': 20},
#  {'color': (135, 172, 81), 'tag': '중요', 'size': 20},
#  {'color': (231, 28, 127), 'tag': '은', 'size': 20},
#  {'color': (1, 28, 129), 'tag': '자유로운', 'size': 20},
#  {'color': (136, 135, 190), 'tag': '풍요', 'size': 20},
#  {'color': (20, 205, 206), 'tag': '경제적', 'size': 20},
#  {'color': (218, 243, 107), 'tag': '구성원', 'size': 20},
#  {'color': (3, 53, 118), 'tag': '개인', 'size': 20},
#  {'color': (144, 52, 7), 'tag': '침해', 'size': 20},
#  {'color': (122, 158, 245), 'tag': '되', 'size': 20},
#  {'color': (16, 184, 255), 'tag': '공정한', 'size': 20},
#  {'color': (129, 22, 29), 'tag': '회', 'size': 20},
#  {'color': (170, 219, 89), 'tag': '보장', 'size': 20},
#  {'color': (89, 179, 129), 'tag': '연대해', 'size': 20},
#  {'color': (75, 208, 194), 'tag': '국가', 'size': 20},
#  {'color': (17, 188, 40), 'tag': '존엄', 'size': 20},
#  {'color': (166, 30, 20), 'tag': '방향', 'size': 20},
#  {'color': (195, 254, 166), 'tag': '뿐', 'size': 20},
#  {'color': (175, 248, 158), 'tag': '도약', 'size': 20},
#  {'color': (21, 11, 75), 'tag': '존중', 'size': 20},
#  {'color': (223, 227, 21), 'tag': '협력', 'size': 20},
#  {'color': (10, 54, 109), 'tag': '한반도', 'size': 20},
#  {'color': (208, 139, 89), 'tag': '아시아', 'size': 20},
#  {'color': (232, 19, 242), 'tag': '핵', 'size': 20},
#  {'color': (60, 147, 251), 'tag': '개발', 'size': 20},
#  {'color': (91, 195, 198), 'tag': '비핵화', 'size': 20},
#  {'color': (81, 50, 157), 'tag': '경제', 'size': 20},
#  {'color': (134, 48, 70), 'tag': '적', 'size': 20},
#  {'color': (177, 80, 116), 'tag': '국제', 'size': 20},
#  {'color': (21, 158, 106), 'tag': '주도적', 'size': 20},
#  {'color': (21, 234, 240), 'tag': '750', 'size': 10},
#  {'color': (130, 29, 111), 'tag': '재외동포', 'size': 10},
#  {'color': (248, 31, 122), 'tag': '시장경제', 'size': 10}]

# %%
img_wordcloud = 'wordcloud/yoon_speech_2022.png'
draw_cloud(speech_tags, img_wordcloud, fontname='Korean', size=(1000, 800))
Image(img_wordcloud)

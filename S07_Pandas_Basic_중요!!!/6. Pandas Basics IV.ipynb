# %% [markdown]
# # Pandas Basic IV

# %%
# Pandas Basics
from IPython.display import Image 

from pandas import Series, DataFrame
import pandas as pd
import numpy as np

# %% [markdown]
# ### 4. Handling missing data
# > 누락된 데이터 처리하기
#
# - pandas의 설계 목표 중 하나는 누락 데이터를 가능한 한 쉽게 처리할 수 있도록 하는 것이다.
# - pandas는 누락된 데이터를 실수든 아니든 모두 NaN(Not a Number)으로 취급한다.
# - 그래서 누락된 값을 쉽게 찾을 수 있다.

# %%
string_data = Series(['aardvark', 'artichoke', np.nan, 'avocado'])
string_data
# Out:
# 0     aardvark
# 1    artichoke
# 2          NaN
# 3      avocado
# dtype: object

# %%
string_data.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
string_data[0] = None
string_data.isnull()
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# dtype: bool

# %% [markdown]
# ### Filtering out missing data
# > 누락된 데이터 골라내기
#
# - Series에 대해 dropna 메소드를 적용하면, 실제 데이터가 들어있는 색인값과 Series값으로 반환한다.

# %%
from numpy import nan as NA
data = Series([1, NA, 3.5, NA, 7])
data.dropna()
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
data[data.notnull()]
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
data = DataFrame([[1., 6.5, 3.],[1., NA, NA],[NA, NA, NA],[NA, 6.5, 3.]])
data
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %%
cleaned = data.dropna()
cleaned
# Out:
#      0    1    2
# 0  1.0  6.5  3.0

# %%
data.dropna(how = 'all')  # how = 'all'  =>  모든 값이 NA인 Row만 제외함
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 3  NaN  6.5  3.0

# %%
data[4] = NA

# %%
data
# Out:
#      0    1    2   4
# 0  1.0  6.5  3.0 NaN
# 1  1.0  NaN  NaN NaN
# 2  NaN  NaN  NaN NaN
# 3  NaN  6.5  3.0 NaN

# %%
data.dropna(axis = 1, how = 'all')
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %%
df = DataFrame(np.random.randn(7,3))
df
# Out:
#           0         1         2
# 0  0.239685 -0.840354  0.507486
# 1  0.610204 -1.447994  0.539701
# 2  0.133834  0.093790  0.246034
# 3  1.351323  0.322845  0.730635
# 4  0.134300 -0.886549  3.288666
# 5 -0.414705  0.361732 -0.235195
# 6  0.994256 -0.073413  0.872890

# %%
df.iloc[:4,1] = NA
df.iloc[:2,2] = NA
df
# Out:
#           0         1         2
# 0  0.239685       NaN       NaN
# 1  0.610204       NaN       NaN
# 2  0.133834       NaN  0.246034
# 3  1.351323       NaN  0.730635
# 4  0.134300 -0.886549  3.288666
# 5 -0.414705  0.361732 -0.235195
# 6  0.994256 -0.073413  0.872890

# %%
df.dropna(thresh = 3)   # thresh : 몇 개 이상의 값이 들어있는 로우만 살펴보고 싶을때 넣는 인자값
# Out:
#           0         1         2
# 4  0.134300 -0.886549  3.288666
# 5 -0.414705  0.361732 -0.235195
# 6  0.994256 -0.073413  0.872890

# %%
df.dropna(thresh = 2)
# Out:
#           0         1         2
# 2  0.133834       NaN  0.246034
# 3  1.351323       NaN  0.730635
# 4  0.134300 -0.886549  3.288666
# 5 -0.414705  0.361732 -0.235195
# 6  0.994256 -0.073413  0.872890

# %%
df.dropna(thresh = 1)
# Out:
#           0         1         2
# 0  0.239685       NaN       NaN
# 1  0.610204       NaN       NaN
# 2  0.133834       NaN  0.246034
# 3  1.351323       NaN  0.730635
# 4  0.134300 -0.886549  3.288666
# 5 -0.414705  0.361732 -0.235195
# 6  0.994256 -0.073413  0.872890

# %% [markdown]
# ### Filling in missing data
# > 누락된 값 채우기

# %%
df
# Out:
#           0         1         2
# 0  0.239685       NaN       NaN
# 1  0.610204       NaN       NaN
# 2  0.133834       NaN  0.246034
# 3  1.351323       NaN  0.730635
# 4  0.134300 -0.886549  3.288666
# 5 -0.414705  0.361732 -0.235195
# 6  0.994256 -0.073413  0.872890

# %%
df.fillna(0)
# Out:
#           0         1         2
# 0  0.239685  0.000000  0.000000
# 1  0.610204  0.000000  0.000000
# 2  0.133834  0.000000  0.246034
# 3  1.351323  0.000000  0.730635
# 4  0.134300 -0.886549  3.288666
# 5 -0.414705  0.361732 -0.235195
# 6  0.994256 -0.073413  0.872890

# %%
df.fillna({1 : 0.5, 3 : -1})
# Out:
#           0         1         2
# 0  0.239685  0.500000       NaN
# 1  0.610204  0.500000       NaN
# 2  0.133834  0.500000  0.246034
# 3  1.351323  0.500000  0.730635
# 4  0.134300 -0.886549  3.288666
# 5 -0.414705  0.361732 -0.235195
# 6  0.994256 -0.073413  0.872890

# %%
df.fillna(0, inplace = True)    # inplace 통해 na값 0으로 실제 채워넣음
df
# Out:
#           0         1         2
# 0  0.239685  0.000000  0.000000
# 1  0.610204  0.000000  0.000000
# 2  0.133834  0.000000  0.246034
# 3  1.351323  0.000000  0.730635
# 4  0.134300 -0.886549  3.288666
# 5 -0.414705  0.361732 -0.235195
# 6  0.994256 -0.073413  0.872890

# %%
df = DataFrame(np.random.randn(6,3))
df.iloc[2:,1] = NA
df.iloc[4:,2] = NA
df
# Out:
#           0         1         2
# 0 -0.802631  0.074146  1.008342
# 1  1.220098 -0.970185 -0.023775
# 2 -0.940300       NaN  1.319269
# 3  0.621869       NaN  0.598882
# 4  0.491890       NaN       NaN
# 5  1.124791       NaN       NaN

# %%
df.fillna(method = 'ffill')
# (2,1) NaN값 : column 기준으로 하기 때문에 (2,0)값이 아닌 (1,1)의 값으로 채워진다!!!!!!!!!!!!!!!

# Q) 만약 (2,0)의 값으로 바꾸고 싶다면??
# A) 기존 data frame을 T 통해 행렬 변환 후 ffill로 값 채우고 다시 T를 통해 행렬변환!!!!!!!!!!!!!!
# Out:
#           0         1         2
# 0 -0.802631  0.074146  1.008342
# 1  1.220098 -0.970185 -0.023775
# 2 -0.940300 -0.970185  1.319269
# 3  0.621869 -0.970185  0.598882
# 4  0.491890 -0.970185  0.598882
# 5  1.124791 -0.970185  0.598882

# %%
# ?df.fillna

# %%
df.fillna(method = 'ffill', limit = 2) # limit = 2    => 2개까지만 채워넣음
# Out:
#           0         1         2
# 0  0.208073  0.702382  2.285916
# 1 -0.331176 -0.304657 -3.636535
# 2 -0.517874 -0.304657  0.923605
# 3  0.186768 -0.304657 -0.865628
# 4  0.112410       NaN -0.865628
# 5  0.482420       NaN -0.865628

# %%
data = Series([1., NA, 3.5, NA, 7])
data.fillna(data.mean())
# Out:
# 0    1.000000
# 1    3.833333
# 2    3.500000
# 3    3.833333
# 4    7.000000
# dtype: float64

# %% [markdown]
# ### 요온연습

# %%
df = DataFrame(np.random.randn(6,3))
df.iloc[2:,1] = NA
df.iloc[4:,2] = NA
df
# Out:
#           0         1         2
# 0  1.616410 -0.039057  0.468421
# 1  1.217106  0.996838  0.231059
# 2  0.354475       NaN -0.622454
# 3  0.590053       NaN -0.310647
# 4 -0.745349       NaN       NaN
# 5 -0.894728       NaN       NaN

# %%
df2 = df.T
df2
# Out:
#           0         1         2         3         4         5
# 0  1.616410  1.217106  0.354475  0.590053 -0.745349 -0.894728
# 1 -0.039057  0.996838       NaN       NaN       NaN       NaN
# 2  0.468421  0.231059 -0.622454 -0.310647       NaN       NaN

# %%
df2 = df2.fillna(method = 'ffill')
df2
# Out:
#           0         1         2         3         4         5
# 0  1.616410  1.217106  0.354475  0.590053 -0.745349 -0.894728
# 1 -0.039057  0.996838  0.354475  0.590053 -0.745349 -0.894728
# 2  0.468421  0.231059 -0.622454 -0.310647 -0.745349 -0.894728

# %%
df1 = df2.T
df1
# Out:
#           0         1         2
# 0  1.616410 -0.039057  0.468421
# 1  1.217106  0.996838  0.231059
# 2  0.354475  0.354475 -0.622454
# 3  0.590053  0.590053 -0.310647
# 4 -0.745349 -0.745349 -0.745349
# 5 -0.894728 -0.894728 -0.894728

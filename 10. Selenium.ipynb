# %% [markdown]
# # Selenium 개요
# - BeautifulSopu 패키지만을 사용하여 크롤링을 할 경우, 모든 웹페이지의 데이터들을 가져오는 것은 아니다.
# - 예를들어, 비동기적으로 뒤늦게 웹페이지의 정보를 업데이트하는 경우와 로그인이나 특정권한을 요구하는 웹페이지의 경우가 그럴것이다.
# - 이때 필요로 하는 패키지가 바로 셀레늄(Selenium)이며, 별도의 webdriver라는 API를 통해 운영체제에 설치된 브라우저를 제어할 수 있다.
# - 즉, 셀레늄을 사용하면 웹페이지상에서 눈에 보이는 모든 데이터를 가져올 수 있다.
# - 참조 : http://www.seleniumhq.org/projects/webdriver/

# %% [markdown]
# ### Selenium 환경 설정 방법
# >1. Selenium Package Install
# - Anaconda Prompt 에서 Selnium 설치
# - (base) C:> pip install selenium
# >2. Webdriver Down & Install
# - 가장 보편적으로 많이 사용하는 크롬 웹드라이브를 다운받아서 설치한다.
# - 아래 사이트에서 OS에 맞는 웹드라이브를 다운받아 압축을 풀어 driver 폴더에 복사해둔다.
# - 크롬 웹드라이브 다운 :
# - https://chromedriver.chromium.org/downloads
# - https://chromedriver.storage.googleapis.com/index.html?path=2.35/

# %% [markdown]
# ### Selenium 예제

# %%
# !pip install selenium

# %%
# %ls ..\driver\

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from IPython.display import Image

import re

# %%
# 웹드라이브로 크롬브라우즈 띄운다.
driver_path = "../driver/chromedriver.exe"
driver = webdriver.Chrome(executable_path=driver_path)
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_12828\3620293503.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=driver_path)

# %%
# !echo %PATH%

# %%
url_page = 'http://www.seleniumhq.org/projects/webdriver/'
url_page = 'https://www.tutorialspoint.com/selenium/'
driver.get(url_page)

# %%
from selenium.webdriver.common.by import By

# %%
# Selenium - WebDriver
# driver.find_element_by_css_selector('#tocCollapse > div > ul:nth-child(3) > li:nth-child(8) > a').click()

# %%
# Selenium - WebDriver
driver.find_element_by_css_selector('#tocCollapse > div > ul:nth-child(3) > li:nth-child(8) > a').click()

# %%
capture_img = './images/selenium_webdriver.png'
driver.save_screenshot(capture_img)
Image(capture_img)

# %% [markdown]
# ### 네이버 크롤링

# %%
url_page = 'https://www.naver.com'
driver.get(url_page)

# %%
# XQury
# driver.find_element_by_xpath('//*[@id="NM_FAVORITE"]/div[1]/a').click()

# jQuery
# 더보기
driver.find_element_by_css_selector('#NM_FAVORITE > div.group_nav > a').click()

# %%
# 영화 클릭
driver.find_element_by_css_selector('#gnb > div.ly_service > div.group_service.NM_FAVORITE_ALL_LY > dl:nth-child(3) > dd:nth-child(3) > a').click()

# %%
# 영화 랭킹 클릭
driver.find_element_by_css_selector('#scrollbar > div.scrollbar-box > div > div > ul > li:nth-child(3) > a').click()

# %%
# 랭킹1등 클릭
driver.find_element_by_css_selector('#old_content > table > tbody > tr:nth-child(2) > td.title > div > a').click()

# %%
# 리뷰 
driver.find_element_by_css_selector('#movieEndTabMenu > li:nth-child(6) > a').click()

# %%
current_url = driver.current_url
current_url

# %%
# pattern = re.compile("[\d+,?]+")
pattern = re.compile("\d{6}")
result = pattern.findall(current_url)
code = result[0] if len(result)>0 else ''
code

# %%
review_url = current_url.replace(code, '{}')
review_url

# %% [markdown]
# ### NAVER 영화 리뷰페이지로 바로 이동

# %%
url_page = 'https://www.naver.com'
driver.get(url_page)

# %%
# XQury
# driver.find_element_by_xpath('//*[@id="NM_FAVORITE"]/div[1]/a').click()

# jQuery
# 더보기
driver.find_element_by_css_selector('#NM_FAVORITE > div.group_nav > a').click()
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_12828\866670355.py:6: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   driver.find_element_by_css_selector('#NM_FAVORITE > div.group_nav > a').click()

# %%
# 영화 클릭
driver.find_element_by_css_selector('#gnb > div.ly_service > div.group_service.NM_FAVORITE_ALL_LY > dl:nth-child(3) > dd:nth-child(3) > a').click()
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_12828\2554049513.py:2: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   driver.find_element_by_css_selector('#gnb > div.ly_service > div.group_service.NM_FAVORITE_ALL_LY > dl:nth-child(3) > dd:nth-child(3) > a').click()

# %%
# 영화제목 검색키 입력
movie_title = '브로커'
driver.find_element_by_css_selector('#ipt_tx_srch').send_keys(movie_title)
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_12828\947546459.py:3: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   driver.find_element_by_css_selector('#ipt_tx_srch').send_keys(movie_title)

# %%
# 검색 클릭
driver.find_element_by_css_selector('#jSearchArea > div > button').click()
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_12828\3545458147.py:2: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   driver.find_element_by_css_selector('#jSearchArea > div > button').click()

# %%
# 아이유가 출연한 첫번째링크롤 GO 
driver.find_element_by_css_selector('#old_content > ul:nth-child(4) > li:nth-child(1) > dl > dt > a > strong').click()
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_12828\1951075234.py:2: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   driver.find_element_by_css_selector('#old_content > ul:nth-child(4) > li:nth-child(1) > dl > dt > a > strong').click()

# %%
# 리뷰
driver.find_element_by_css_selector('#movieEndTabMenu > li:nth-child(6) > a').click()
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_12828\325053931.py:2: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   driver.find_element_by_css_selector('#movieEndTabMenu > li:nth-child(6) > a').click()

# %%
# 첫번째 페이지로 이동
driver.find_element_by_css_selector('#pagerTagAnchor1 > span').click()
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_12828\287774269.py:2: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   driver.find_element_by_css_selector('#pagerTagAnchor1 > span').click()

# %%
# 페이지 BeautifulSoup 객체로 가져온다
html = driver.page_source
soup = BeautifulSoup(html, "lxml")

# %%
soup.title
# Out:
# <title>브로커 : 네이버 영화</title>

# %%
current_url = driver.current_url
current_url
# Out:
# 'https://movie.naver.com/movie/bi/mi/review.naver?code=196854&page=1'

# %%
pattern = re.compile("\d{6}")
result = pattern.findall(current_url)
code = result[0] if len(result)>0 else ''
code
# Out:
# '196854'

# %%
# 리뷰페이지 캡처후 저장
capture_img = './images/naver_movie_{code}.png'.format(code=code)
driver.save_screenshot(capture_img)
Image(capture_img)

# %%
# 리뷰페이지로 바로 이동
review_url = current_url
url_page = review_url.format(code)
driver.get(url_page)

# %%
html = driver.page_source
soup = BeautifulSoup(html, "lxml")
soup.title
# Out:
# <title>브로커 : 네이버 영화</title>

# %%
movie_title = soup.title.get_text().split(':')[0].strip()
movie_title
# Out:
# '브로커'

# %%
review_cnt = soup.find("span","cnt")
review_cnt
# Out:
# <span class="cnt">총<em>13</em>건</span>

# %%
review_cnt2 = review_cnt.find("em").get_text()
review_cnt2
# Out:
# '13'

# %%
review_cnt_total = int(review_cnt2.replace(',', ''))
review_cnt_total
# Out:
# 13

# %%
last_page = review_cnt_total//10 + 1
last_page
# Out:
# 2

# %%
'영화 "{}"의 리뷰수는 총 {}건이며, 마지막 페이지는 {} 입니다.'.format(movie_title, review_cnt_total, last_page)
# Out:
# '영화 "브로커"의 리뷰수는 총 13건이며, 마지막 페이지는 2 입니다.'

# %%
# 리뷰 마지막 페이지로 이동
url_page = 'https://movie.naver.com/movie/bi/mi/review.nhn?code={}&page={}'.format(code, last_page)
driver.get(url_page)
